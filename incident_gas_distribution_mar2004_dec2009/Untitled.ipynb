# %%
import pandas as pd

# %%
# Replace 'your_file.txt' with the path to your file
file_path = 'accident_hazardous_liquid_jan2010_present.txt'

# Read the tab-delimited file into a DataFrame
df = pd.read_csv(file_path, delimiter='\t', encoding='latin1')

# Now you can work with your DataFrame 'df'
# Out:
# C:\Users\zacha\AppData\Local\Temp\ipykernel_25624\664230418.py:5: DtypeWarning: Columns (12,13,44,50,51,52,54,57,59,60,61,64,65,66,68,69,70,72,73,74,75,76,91,93,94,95,96,102,104,105,107,108,109,110,111,113,118,120,121,128,131,134,135,136,137,138,140,143,145,146,147,148,149,150,159,161,163,166,175,195,196,197,226,227,228,229,230,235,241,245,247,248,270,272,286,289,294,295,302,307,311,312,328,342,343,350,351,353,354,356,357,359,360,365,367,368,369,370,371,377,378,379,389,393,394,395,398,404,407,408,410,414,415,420,424,431,432,433,436,437,438,440,444,445,446,450,451,452,463,466,468,469,470,476,493,504,505,506,507,508,510,511,512,513,516,517,520,521,524,525,527,528,530,531,533,536,537,539,541,542,544,555,557,558,565,567,568,582,584,585,586,587,588,589,590,591,592,593,594,596,597,601,604,606,607,610,611,612,613,614,615,619,620,621,622,623,624,625,626,628,629,630,631,632,633,640,641,642) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df.columns
# Out:
# Index(['REPORT_RECEIVED_DATE', 'IYEAR', 'REPORT_NUMBER', 'SUPPLEMENTAL_NUMBER',
#        'REPORT_TYPE', 'OPERATOR_ID', 'NAME', 'OPERATOR_STREET_ADDRESS',
#        'OPERATOR_CITY_NAME', 'OPERATOR_STATE_ABBREVIATION',
#        ...
#        'PREPARER_FAX', 'PREPARED_DATE', 'LOCAL_CONTACT_NAME',
#        'LOCAL_CONTACT_EMAIL', 'LOCAL_CONTACT_TELEPHONE', 'AUTHORIZER_NAME',
#        'AUTHORIZER_TELEPHONE', 'AUTHORIZER_TITLE', 'AUTHORIZER_EMAIL',
#        'NARRATIVE'],
#       dtype='object', length=648)

# %%
df.head()
# Out:
#   REPORT_RECEIVED_DATE  IYEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0            4/24/2024   2024       20240098                39482
# 1            4/11/2024   2024       20240088                39460
# 2            4/28/2024   2024       20240101                39498
# 3            4/26/2024   2024       20240100                39497
# 4            4/24/2024   2024       20240099                39485
#
#           REPORT_TYPE  OPERATOR_ID                                  NAME  \
# 0            ORIGINAL        32688  WEST COAST TERMINAL PIPELINE  (WCTP)
# 1  SUPPLEMENTAL FINAL        32147                MARATHON PIPE LINE LLC
# 2            ORIGINAL        31970           CONOCOPHILLIPS ALASKA, INC.
# 3            ORIGINAL        31460     DOD DEFENSE ENERGY SUPPORT CENTER
# 4            ORIGINAL          300                 PLAINS PIPELINE, L.P.
#
#                   OPERATOR_STREET_ADDRESS OPERATOR_CITY_NAME  \
# 0         1001 LOUISIANA ST.,  SUITE 1000            HOUSTON
# ...

# %%
df.loc[0]['NARRATIVE']
# Out:
# "WHILE CONDUCTING A ROUTINE FACILITY INSPECTION AT 10:45 LOCAL TIME ON 4/2/2024, A GRAVEL AREA CONTAMINATED WITH JET FUEL WAS DISCOVERED AT THE MAIN CLEAN PRODUCTS MANIFOLD AREA OF CARSON TERMINAL. THE KINDER MORGAN ERL PROCESS WAS INITIATED, PIPELINES SHUT DOWN, AND CALIFORNIA AND NRC NOTIFICATIONS WERE COMPLETED. EMERGENCY EXCAVATION ACTIVITIES BEGAN AND, AT APPROXIMATELY 22:15, A PIN HOLE LEAK WAS IDENTIFIED ON AN UNDERGROUND 4-INCH LINE ASSOCIATED WITH CARSON'S FULL-FLOW RELIEF SYSTEM. REPAIRS WERE MADE, PRESSURE TEST CONDUCTED, AND NORMAL OPERATIONS RESUMED AT APPROXIMATELY 01:18 ON 4/3/2024. THE CAUSE OF THE RELEASE IS UNDER INVESTIGATION."
