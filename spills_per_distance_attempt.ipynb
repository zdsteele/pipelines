# %%
import math
import json
import pandas as pd
from fuzzywuzzy import fuzz

# %%
# Read the GeoJSON file
with open('nat_gas_pipelines.geojson', 'r') as f:
    data = json.load(f)

# Access the features in the GeoJSON file
gas_features = data['features']

with open('crude_oil_pipelines.geojson', 'r') as f:
    data = json.load(f)
    
oil_features = data['features']

# %%
for feature in oil_features:
    if 'Opername' in feature['properties']:
        feature['properties']['Operator'] = feature['properties'].pop('Opername')

# %%
features = gas_features + oil_features

# %%
def calculate_total_distance(features):
    """
    Calculates the total distance of all LineString and MultiLineString geometries in the given list of feature dictionaries.
    
    Args:
        features (list): A list of feature dictionaries, each with a 'geometry' key containing a LineString or MultiLineString geometry.
    
    Returns:
        float: The total distance of all LineString and MultiLineString geometries.
    """
    total_distance = 0
    
    for feature in features:
        geometry = feature.get('geometry', None)
        if geometry is None:
            continue
        
        geometry_type = geometry['type']
        coordinates = geometry['coordinates']
        
        if geometry_type == 'LineString':
            for i in range(len(coordinates) - 1):
                x1, y1 = coordinates[i]
                x2, y2 = coordinates[i+1]
                total_distance += math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
        elif geometry_type == 'MultiLineString':
            for linestring in coordinates:
                for i in range(len(linestring) - 1):
                    x1, y1 = linestring[i]
                    x2, y2 = linestring[i+1]
                    total_distance += math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    
    return total_distance

# %%
operators = {}

for x in features:
    
    distance = calculate_total_distance([x])
    x['properties']['Distance'] = distance
    
    operator = x['properties']['Operator'].lower()
    
    
    
    
    if operator in operators:
        operators[operator] = operators[operator] + distance
    else:
        operators[operator] = distance

# %%
operators = dict(sorted(operators.items()))
operators
# Out:
# {'acadian gas gathering system': 176803.96989088127,
#  'acadian gas pipeline sys': 779991.4653032126,
#  'acadian haynesville pipeline': 420246.51732460444,
#  'agua blanca pipeline': 293457.5269052594,
#  'algonquin gas trans co': 1484989.3875583948,
#  'alliance pipeline system': 2191554.4498700704,
#  'alpine transportation': 146767.15921392798,
#  'alyeska pipeline': 2890455.5393740647,
#  'amoco pipeline co': 681045.2258404586,
#  'anr pipeline co': 14760059.120665118,
#  'anr storage co': 44357.83858625556,
#  'arkansas western llc': 1080388.0268663904,
#  'atmos energy (united cities gas co)': 15817.48516889234,
#  'atmos pipeline - texas': 10169733.543215264,
#  'birdsboro pipeline': 27422.670585787506,
#  'bison pipeline': 672233.6746152296,
#  'black marlin pipeline co': 222597.567206034,
#  'blue dolphin pipeline co': 173534.5002374365,
#  'bluewater pipeline co': 74125.09506172959,
#  'bp pipeline (alaska)': 396413.0841004106,
#  'bp pipeline (north america)': 1398038.373508439,
#  'bridgeline holdings pipeline lp': 1218384.835281402,
#  'bridger pipeline': 866089.754935275,
#  'brooklyn union gas co': 468397.42972149036,
#  'butte pipeline': 690332.2058038968,
#  'california gas transmission co': 7114628.570305713,
#  'canton pipeline': 96171.49084288506,
#  'canyon creek compression co': 395.73836466342124,
#  'cardinal pipeline co': 149065.32781084854,
#  'centana pipeline co (la)': 101312.89683284728,
#  'centana pipeline co (tx)': 679960.6879643231,
#  'centra minnesota pipeline co': 150536.56224124646,
#  'centra pipeline co': 13165.588741623773,
#  'centurion pipeline': 2259208.7272014716,
#  'chandeleur pipeline co': 204717.6023828215,
#  'chandeleur pipeline co (mags)': 50398.22748738629,
#  'cheyenne plains pipeline co': 778128.6053663981,
#  'chs energy': 2566967.275145665,
#  'cimarron river pipeline': 759089.7727192516,
#  'colorado interstate gas co': 5883419.106669956,
#  'columbia gas trans co': 17359273.18128474,
#  'columbia gulf pipeline': 3959077.2402167264,
#  'comanche trail pipeline': 362015.34908358526,
#  'constitution pipeline': 58353.46629091121,
#  'coos county pipeline': 180945.5673740109,
#  'coral energy pipeline co': 898477.3179538819,
#  'cornerstone pipeline co': 27552.383037122418,
#  'corpus christi pipeline': 42249.76931180932,
#  'cove point pipeline': 171983.46440119634,
#  'creole pipeline co': 56620.07823372893,
#  'crossroads pipeline co': 438194.6322210028,
#  'crosstex alabama system': 232381.66739812255,
#  'crosstex arkoma system': 237560.41360262225,
#  'crosstex mississippi pipeline': 1727189.5383938071,
#  'crosstex texas systems': 2253854.0809264216,
#  'dauphin island gathering system': 599304.7457673626,
#  'delek logistics': 568441.3660238445,
#  'destin pipeline offshore (shell)': 544024.6241860337,
#  'discovery pipeline system': 407850.0271082957,
#  'dominion transmission co': 5418300.990560644,
#  'dow pipeline co (la)': 343189.8861619851,
#  'dow pipeline co (tx)': 622602.3222208079,
#  'east ohio gas co': 2727957.1119406275,
#  'east tennessee gas co': 1987080.2153450688,
#  'east west project mainline': 499997.17244335584,
#  'eastern shore nat gas co': 694782.0253186511,
#  'el paso natural gas co': 14054399.02973362,
#  'el paso texas pipeline co': 12804289.522798454,
#  'elba express pipeline': 359117.1902044175,
#  'empire pipeline': 558307.5010615173,
#  'enable gas transmission': 12697153.488602519,
#  'enbridge': 18207380.330216598,
#  'enbridge pipelines (alatenn)': 448077.3435719144,
#  'enbridge pipelines (east texas)': 4768820.505442308,
#  'enbridge pipelines (utos)': 57758.314110694766,
#  'energy transfer': 11367532.822747182,
#  'energynorth nat gas co': 76097.67410609413,
#  'eni us operating': 60526.0707057725,
#  'enogex inc': 4570188.495637679,
#  'enterprise products partners': 3906002.7568657254,
#  'epic': 1153792.338541505,
#  'equitrans inc': 2307744.298936181,
#  'ergon': 77929.95835782909,
#  'etc tiger pipeline': 326103.2141459154,
#  'evangeline gas pipeline': 55263.574576696,
#  'exxonmobil': 72622.9032577107,
#  'exxonmobil west coast': 351821.8650310536,
#  'fayetteville express pipeline': 351410.4882924532,
#  'florida gas trans co': 7027555.03285698,
#  'florida southeast connection': 215825.79942691562,
#  'garden banks auger 1 line': 64598.13277244292,
#  'gas transmission - northwest': 1361736.0313595366,
#  'genesis energy': 316456.79017864325,
#  'granite state gas trans co': 190979.18868039368,
#  'grasslands pipeline': 669233.6951510521,
#  'great lakes gas trans co': 2308765.3570135674,
#  'guardian pipeline co': 342466.4380548013,
#  'gulf coast express': 766601.7696884321,
#  'gulf connector expansion project': 889257.2638380942,
#  'gulf south pipeline co': 11607331.687862284,
#  'gulf xpress': 1040740.6308462082,
#  'gulfstream pipeline co': 1368242.6614170547,
#  'heartland pipeline co': 54259.68216804251,
#  'high island offshore': 599382.4335562004,
#  'holly energy': 1104308.897488639,
#  'hope natural gas co': 393104.6360483695,
#  'horizon pipeline co': 55973.09304928569,
#  'houston pipeline co': 8302952.611107269,
#  'hunt crude oil supply': 407917.0647983748,
#  'hutchinson pipeline': 201505.24903063045,
#  'impulsora pipeline': 29871.667876694497,
#  'independence trail pipeline co': 238762.78236353968,
#  'iroquois gas trans co': 899945.1395082943,
#  'kelso-beaver pipeline': 43601.61686423263,
#  'kenai kachemak pipeline': 102187.4808169082,
#  'kentucky-west virginia gas co': 1047866.8110080835,
#  'kern river gas trans co': 1899338.0189838684,
#  'keystone gas (sold to in 2005)': 87017.63721401282,
#  'kinder morgan': 2981504.3921311684,
#  'kinder morgan louisiana pipeline': 244462.39453250173,
#  'kinder morgan texas pipeline co': 8035177.2535311915,
#  'ko transmission co': 6483.131965077901,
#  'koch pipeline': 3240682.6854403755,
#  'kuparuk transportation': 158128.60891759957,
#  'loop': 186592.2744726499,
#  'louisiana gas co': 1023876.5171434325,
#  'louisiana intrastate gas co': 2640534.3187872707,
#  'magellan midstream partners': 3250961.0154766366,
#  'marathon': 2062797.645216449,
#  'maritimes & northeast pl us': 500258.29413065506,
#  'markwest michigan pipeline': 212590.49674502973,
#  'medallion': 108702.17383219619,
#  'mgtc pipeline system': 553552.6416574611,
#  'michcon gas co': 3419488.6223174194,
#  'michigan gas storage co': 983711.5577925212,
#  'midcontinent express pipeline': 931250.3572337944,
#  'midla-natchez pipeline': 93813.71362047,
#  'midwestern gas trans co': 747493.5365360042,
#  'migc pipeline system': 536713.734375273,
#  'millennium pipeline co': 510786.11627091264,
#  'mississippi canyon gathering': 10834.49514232412,
#  'mississippi canyon gathering (mars)': 77911.07231324686,
#  'mississippi canyon gathering (shell)': 121600.84668069215,
#  'mississippi canyon gathering (ursa)': 86937.24427133377,
#  'mississippi canyon gathering system': 69191.22859475283,
#  'mississippi river trans corp': 4070672.484937039,
#  'mississippi valley gas co': 1081463.3815270108,
#  'missouri gas co': 133544.65757805394,
#  'missouri interstate gas, llc': 13476.014241383175,
#  'missouri pipeline co': 292727.9395804782,
#  'missouri public service co': 376770.0193112148,
#  'mojave pipeline co': 682426.031318641,
#  'monterey pipeline co': 818248.5677147575,
#  'mustang fuel co': 111039.10550585944,
#  'national fuel gas distr co': 2751490.0541119426,
#  'national fuel gas supply co': 3058422.4599356456,
#  'natural gas pl co of am': 10948178.568507597,
#  'nautilus pipeline system': 180470.60402139727,
#  'net mexico pipeline': 219830.33612411623,
#  'nexus gas transmission': 527724.9524643184,
#  'nora transmission co': 38050.5206146488,
#  'norse pipeline llc': 611573.7046233312,
#  'north baja pipeline co': 153953.2930927573,
#  'north coast gas transmission co': 398041.0809179591,
#  'north country pipeline co': 49349.11103024863,
#  'north penn gas co': 1404376.8148821988,
#  'northern border pl co': 2846775.1932740933,
#  'northern illinois gas co': 5626164.743339786,
#  'northern natural gas co': 27250422.405126642,
#  'northern utilities (me)': 228164.80599795392,
#  'northwest pipeline': 6559959.6796882665,
#  'northwestern energy co': 6786219.598281769,
#  'nustar energy': 1075275.2924299124,
#  'oasis pipeline': 1608389.9555105872,
#  'oklahoma texas gas co': 56732.167682609535,
#  'oneok gas transmission llc': 4502029.05750603,
#  'oneok gas transportation llc': 9066543.137376998,
#  'oneok westex pipeline': 5652100.08234192,
#  'overland trails trans co': 513369.77980850084,
#  'overthrust pipeline co': 416542.20724445523,
#  'ozark gas transmission, llc': 1295383.652264754,
#  'paiute pipeline co': 1343267.433928827,
#  'panhandle eastern pl co': 5074904.0981921535,
#  'panther interstate pipeline llc': 74578.51230804503,
#  'pecan pipeline company': 50026.16430572456,
#  'penn york energy co': 31125.396178323073,
#  'peoples gas co (tx)': 301533.9911960789,
#  'permian express partners': 3416822.9611947546,
#  'petal gas storage co': 121641.79416450742,
#  'phillips  66 pipeline': 44508.283055701475,
#  'phillips 66 pipeline': 4939317.872285504,
#  'plains all american pipeline': 8641261.388651598,
#  'pngts/maritimes & northeast': 248548.68302012415,
#  'pony express pipeline': 1494120.8860645576,
#  'portland natural gas pl': 408920.16251620563,
#  'portland pipeline': 504362.2137315967,
#  'public service co of nc': 1111094.9754118596,
#  'public service co of nm': 2286463.186834118,
#  'questar pipeline co': 3141283.196438379,
#  'questar southern trails line': 936786.6402123523,
#  'red bluff express pipeline': 136631.4289938099,
#  'revolution pipeline': 78331.77536324262,
#  'risberg line': 113430.8108897716,
#  'roadrunner': 374248.43789708987,
#  'roadrunner eastbound': 363640.84318787465,
#  'rockies express (echo springs lateral)': 11427.876106369213,
#  'rockies express (entrega)': 702919.6034452198,
#  'rockies express pipeline': 2779137.93184347,
#  'rocky mountain natural gas co': 1184003.8377518305,
#  'rover pipeline': 983544.657570139,
#  'ruby pipeline llc': 1395033.2766977903,
#  'sabal trail pipeline': 908056.1087917114,
#  'sabine llc': 290622.6831983716,
#  'san diego gas & elec co': 251247.44160148082,
#  'sea robin pipeline': 739198.4563889204,
#  'shell pipeline company': 2534062.806165674,
#  'shoshone pipeline': 75866.5459689209,
#  'sierrita gas pipeline': 109220.63916578199,
#  'sonat exploration co': 25271.914688890225,
#  'south carolina pl corp': 2982118.0521827983,
#  'south georgia gas pipeline co': 1677701.5339794336,
#  'southeast supply header pipeline co': 1039735.1092338838,
#  'southern california gas co': 3766628.999964662,
#  'southern natural gas co': 7431840.086702681,
#  'southern pines storage lateral': 49455.14988741586,
#  'southern star central gas pl co': 11484355.126877818,
#  'southern union gas services (tx)': 1096981.929020266,
#  'southwest gas corp': 450301.3434529028,
#  'spectra energy': 3771903.4780410845,
#  'spire st. louis pipeline': 131699.8642655376,
#  'st lawrence gas co': 302584.5618541374,
#  'st. james supply project': 212339.0855993614,
#  'stingray pipeline': 658447.6182958118,
#  'stratton ridge': 357657.2743597003,
#  'sunoco': 6985444.496970659,
#  'tallgrass energy': 1860180.0814864729,
#  'tallgrass interstate gas transmission': 0,
#  'tengasco gas co': 77257.12872601193,
#  'tennessee gas pipeline': 14812432.710607229,
#  'texas eastern trans co': 10490422.50527767,
#  'texas gas transmission co': 6052448.235282206,
#  'texas intrastate pipeline co': 893722.5510669053,
#  'texas louisiana markets project': 227631.09357063047,
#  'the exploration co': 252925.84432037183,
#  'trailblazer pipeline co': 928690.1695780967,
#  'trans pecos pipeline': 266548.842355189,
#  'transcanada': 5670943.798315571,
#  'transcolorado gas trans co': 614741.986846844,
#  'transcontinental gas pl': 11906987.611311775,
#  'transok pipeline co': 5150969.48791705,
#  'transwestern gas co': 5032433.7480646325,
#  'true oil': 1330888.1513124616,
#  'trunkline gas co': 4431298.292283582,
#  'tuscaloosa pipeline co': 55916.2172872684,
#  'tuscarora pipeline co': 613368.9886686159,
#  'union light heat & power': 144754.8624684635,
#  'usg pipeline co': 30433.36854554423,
#  'valley crossing pipeline': 279380.01812673686,
#  'valley gas pipeline co': 58681.47587180999,
#  'vector pipeline co': 711398.9690636323,
#  'venice gas gathering sys': 67087.58000642736,
#  'vermont gas system': 117997.63194276286,
#  'viking gas transmission co': 1408412.2261511148,
#  'virginia natural gas co': 494330.5194775006,
#  'wbi energy transmission': 6207673.461919847,
#  'west ohio gas co': 423971.99566364783,
#  'west texas gas': 550834.3536102711,
#  'western gas': 1082939.437972623,
#  'western refining': 969125.2825858367,
#  'worsham-steed pipeline': 122217.53987274934,
#  'wyoming interstate pl co': 1441777.6279757004}

# %%
df = pd.read_csv('oil_spill_data.csv')
df['Operator Name'] = df['Operator Name'].str.lower()
df_sub = df[['Operator Name', 'Accident Year', 'Net Loss (Barrels)']]
df_sub.head(2)
# Out:
#             Operator Name  Accident Year  Net Loss (Barrels)
# 0   oneok ngl pipeline lp           2010                21.0
# 1  portland pipeline corp           2010                 0.0

# %%
df_grouped = df_sub.groupby(['Operator Name','Accident Year']).sum()
df_grouped
# Out:
#                                            Net Loss (Barrels)
# Operator Name               Accident Year
# alyeska pipeline service co 2010                       1119.0
#                             2011                          0.0
#                             2012                          0.0
#                             2013                          0.0
#                             2015                          0.0
# ...                                                       ...
# wolverine pipeline co       2014                          9.0
#                             2016                          0.0
# wyoming pipeline company    2014                          8.5
#                             2015                         38.0
#                             2016                         11.5
#
# [633 rows x 1 columns]

# %%
# Convert the DataFrame to a dictionary, with 'Name' as the key
data_dict = {}
for name in df['Operator Name'].unique():
    name_group = df_grouped.loc[name]
    data_dict[name] = name_group.to_dict('index')
data_dict
# Out:
# {'oneok ngl pipeline lp': {2010: {'Net Loss (Barrels)': 18623.04},
#   2011: {'Net Loss (Barrels)': 964.0799999999999},
#   2012: {'Net Loss (Barrels)': 24.72}},
#  'portland pipeline corp': {2010: {'Net Loss (Barrels)': 0.0}},
#  'petrologistics olefins, llc': {2010: {'Net Loss (Barrels)': 3.31},
#   2011: {'Net Loss (Barrels)': 5.0},
#   2013: {'Net Loss (Barrels)': 14.0},
#   2014: {'Net Loss (Barrels)': 7.0}},
#  'enbridge energy, limited partnership': {2010: {'Net Loss (Barrels)': 4075.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 1874.0},
#   2013: {'Net Loss (Barrels)': 0.48},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'plains pipeline, l.p.': {2010: {'Net Loss (Barrels)': 2.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 15.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 40.0},
#   2015: {'Net Loss (Barrels)': 1957.0},
#   2016: {'Net Loss (Barrels)': 250.0}},
#  'kinder morgan liquid terminals, llc': {2010: {'Net Loss (Barrels)': 7.0},
#   2011: {'Net Loss (Barrels)': 36.03},
#   2012: {'Net Loss (Barrels)': 0.31},
#   2013: {'Net Loss (Barrels)': 0.76},
#   2014: {'Net Loss (Barrels)': 3.49},
#   2015: {'Net Loss (Barrels)': 21.33},
#   2016: {'Net Loss (Barrels)': 7.16}},
#  'mobil corp': {2010: {'Net Loss (Barrels)': 0.24},
#   2011: {'Net Loss (Barrels)': 1.38},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 1.2},
#   2014: {'Net Loss (Barrels)': 0.54}},
#  'conocophillips': {2010: {'Net Loss (Barrels)': 4639.5},
#   2011: {'Net Loss (Barrels)': 134.63},
#   2012: {'Net Loss (Barrels)': 2.48}},
#  'targa resources operating lp': {2010: {'Net Loss (Barrels)': 2237.0}},
#  'nustar logistics, l.p.': {2010: {'Net Loss (Barrels)': 3.0},
#   2011: {'Net Loss (Barrels)': 0.23},
#   2013: {'Net Loss (Barrels)': 1935.0},
#   2015: {'Net Loss (Barrels)': 9260.6},
#   2016: {'Net Loss (Barrels)': 2.48}},
#  'jayhawk pipeline llc': {2010: {'Net Loss (Barrels)': 7.21},
#   2011: {'Net Loss (Barrels)': 213.8},
#   2012: {'Net Loss (Barrels)': 21.07},
#   2013: {'Net Loss (Barrels)': 135.5},
#   2014: {'Net Loss (Barrels)': 11.5},
#   2015: {'Net Loss (Barrels)': 0.15},
#   2016: {'Net Loss (Barrels)': 202.95}},
#  'plains marketing, l.p.': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.24},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'ccps transportation, llc': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.07},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'magellan ammonia pipeline, l.p.': {2010: {'Net Loss (Barrels)': 467.62},
#   2011: {'Net Loss (Barrels)': 19.79},
#   2012: {'Net Loss (Barrels)': 90.64},
#   2013: {'Net Loss (Barrels)': 57.21},
#   2014: {'Net Loss (Barrels)': 43.27},
#   2015: {'Net Loss (Barrels)': 0.2},
#   2016: {'Net Loss (Barrels)': 1548.1}},
#  'shell pipeline co., l.p.': {2010: {'Net Loss (Barrels)': 560.63},
#   2011: {'Net Loss (Barrels)': 0.24000000000000002},
#   2012: {'Net Loss (Barrels)': 432.11},
#   2013: {'Net Loss (Barrels)': 415.0},
#   2014: {'Net Loss (Barrels)': 1.49},
#   2015: {'Net Loss (Barrels)': 111.77},
#   2016: {'Net Loss (Barrels)': 116.91}},
#  'koch pipeline company, l.p.': {2010: {'Net Loss (Barrels)': 36.54},
#   2011: {'Net Loss (Barrels)': 9.0},
#   2012: {'Net Loss (Barrels)': 2.39},
#   2013: {'Net Loss (Barrels)': 8.66},
#   2014: {'Net Loss (Barrels)': 4.62},
#   2015: {'Net Loss (Barrels)': 8.719999999999999},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'kiantone pipeline corp': {2010: {'Net Loss (Barrels)': 0.04},
#   2014: {'Net Loss (Barrels)': 0.1},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'pacific pipeline system llc': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0}},
#  'te products pipeline company, llc': {2010: {'Net Loss (Barrels)': 3.05}},
#  'magellan pipeline company, lp': {2010: {'Net Loss (Barrels)': 202.53},
#   2011: {'Net Loss (Barrels)': 3415.48},
#   2012: {'Net Loss (Barrels)': 396.75},
#   2013: {'Net Loss (Barrels)': 39.3},
#   2014: {'Net Loss (Barrels)': 11.5},
#   2015: {'Net Loss (Barrels)': 159.32},
#   2016: {'Net Loss (Barrels)': 40.56}},
#  'explorer pipeline co': {2010: {'Net Loss (Barrels)': 1.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 512.96}},
#  'plantation pipe line co': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 4872.8},
#   2015: {'Net Loss (Barrels)': 9.52},
#   2016: {'Net Loss (Barrels)': 0.12}},
#  'nustar pipeline operating partnership l.p.': {2010: {'Net Loss (Barrels)': 3.8299999999999996},
#   2011: {'Net Loss (Barrels)': 103.26},
#   2012: {'Net Loss (Barrels)': 50.2},
#   2013: {'Net Loss (Barrels)': 3.35},
#   2015: {'Net Loss (Barrels)': 1.8},
#   2016: {'Net Loss (Barrels)': 12.4}},
#  'loop inc': {2010: {'Net Loss (Barrels)': 0.0}},
#  'belle fourche pipeline co': {2010: {'Net Loss (Barrels)': 7.12},
#   2011: {'Net Loss (Barrels)': 2675.0},
#   2012: {'Net Loss (Barrels)': 20.0},
#   2013: {'Net Loss (Barrels)': 20.0},
#   2014: {'Net Loss (Barrels)': 5.0},
#   2015: {'Net Loss (Barrels)': 5.0},
#   2016: {'Net Loss (Barrels)': 1402.0}},
#  'semgroup lp': {2010: {'Net Loss (Barrels)': 18.12}},
#  'west shore pipeline co': {2010: {'Net Loss (Barrels)': 0.05},
#   2011: {'Net Loss (Barrels)': 9.5},
#   2012: {'Net Loss (Barrels)': 839.0},
#   2014: {'Net Loss (Barrels)': 0.12},
#   2015: {'Net Loss (Barrels)': 1.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'buckeye partners, lp': {2010: {'Net Loss (Barrels)': 489.7},
#   2011: {'Net Loss (Barrels)': 357.12},
#   2012: {'Net Loss (Barrels)': 114.69999999999999},
#   2013: {'Net Loss (Barrels)': 66.11},
#   2014: {'Net Loss (Barrels)': 52.54},
#   2015: {'Net Loss (Barrels)': 12.48},
#   2016: {'Net Loss (Barrels)': 48.42}},
#  'sunoco pipeline l.p.': {2010: {'Net Loss (Barrels)': 269.24},
#   2011: {'Net Loss (Barrels)': 1127.17},
#   2012: {'Net Loss (Barrels)': 1378.81},
#   2013: {'Net Loss (Barrels)': 772.41},
#   2014: {'Net Loss (Barrels)': 165.79},
#   2015: {'Net Loss (Barrels)': 95.56},
#   2016: {'Net Loss (Barrels)': 8342.43}},
#  'ldh energy pipeline l.p.': {2010: {'Net Loss (Barrels)': 1.0}},
#  'colonial pipeline co': {2010: {'Net Loss (Barrels)': 10.969999999999999},
#   2011: {'Net Loss (Barrels)': 2.79},
#   2012: {'Net Loss (Barrels)': 48.95},
#   2013: {'Net Loss (Barrels)': 27.7},
#   2014: {'Net Loss (Barrels)': 214.51},
#   2015: {'Net Loss (Barrels)': 66.01},
#   2016: {'Net Loss (Barrels)': 12558.99}},
#  'mid - valley pipeline co': {2010: {'Net Loss (Barrels)': 20.0},
#   2011: {'Net Loss (Barrels)': 11.0},
#   2012: {'Net Loss (Barrels)': 2.0},
#   2013: {'Net Loss (Barrels)': 2.18},
#   2014: {'Net Loss (Barrels)': 449.0},
#   2015: {'Net Loss (Barrels)': 5.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'enbridge pipelines (north dakota) llc': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0}},
#  'chaparral energy, llc': {2010: {'Net Loss (Barrels)': 2.99},
#   2013: {'Net Loss (Barrels)': 17.8},
#   2014: {'Net Loss (Barrels)': 1.0},
#   2015: {'Net Loss (Barrels)': 1240.5},
#   2016: {'Net Loss (Barrels)': 1415.1}},
#  'enterprise products operating llc': {2010: {'Net Loss (Barrels)': 10399.720000000001},
#   2011: {'Net Loss (Barrels)': 4764.26},
#   2012: {'Net Loss (Barrels)': 6822.0},
#   2013: {'Net Loss (Barrels)': 19407.65},
#   2014: {'Net Loss (Barrels)': 3403.22},
#   2015: {'Net Loss (Barrels)': 60289.25},
#   2016: {'Net Loss (Barrels)': 7753.400000000001}},
#  'exxonmobil pipeline co': {2010: {'Net Loss (Barrels)': 1.81},
#   2011: {'Net Loss (Barrels)': 1521.94},
#   2012: {'Net Loss (Barrels)': 880.52},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 9.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 681.11}},
#  'sinclair transportation company': {2010: {'Net Loss (Barrels)': 1.0},
#   2012: {'Net Loss (Barrels)': 200.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 105.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'teppco crude pipeline, llc': {2010: {'Net Loss (Barrels)': 4.4}},
#  'sfpp, lp': {2010: {'Net Loss (Barrels)': 42.88},
#   2011: {'Net Loss (Barrels)': 14.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.2},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.89}},
#  'enbridge pipelines (ozark) l.l.c.': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 175.25},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'bp pipeline (north america) inc.': {2010: {'Net Loss (Barrels)': 3.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'sunoco, inc (r&m)': {2010: {'Net Loss (Barrels)': 1.0}},
#  'whitecap pipe line company, l.l.c.': {2010: {'Net Loss (Barrels)': 5.7}},
#  'progress energy': {2010: {'Net Loss (Barrels)': 95.0}},
#  'kinder morgan pipelines (usa) inc': {2010: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0}},
#  'bridger lake, llc': {2010: {'Net Loss (Barrels)': 0.0}},
#  'chevron pipe line co': {2010: {'Net Loss (Barrels)': 597.78},
#   2011: {'Net Loss (Barrels)': 13075.26},
#   2012: {'Net Loss (Barrels)': 3137.26},
#   2013: {'Net Loss (Barrels)': 4359.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'chevron products company': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 9.0}},
#  'valero terminaling and distribution company': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 250.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 24.0}},
#  'marathon pipe line llc': {2010: {'Net Loss (Barrels)': 12.52},
#   2011: {'Net Loss (Barrels)': 2357.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 7.3999999999999995},
#   2014: {'Net Loss (Barrels)': 306.8},
#   2015: {'Net Loss (Barrels)': 151.1},
#   2016: {'Net Loss (Barrels)': 860.1700000000001},
#   2017: {'Net Loss (Barrels)': 0.0}},
#  'houston refining lp.': {2010: {'Net Loss (Barrels)': 0.35},
#   2011: {'Net Loss (Barrels)': 0.05},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'exxonmobil oil corp - west coast': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'calnev pipeline co': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 2.68}},
#  'tesoro - high plains pipeline company': {2010: {'Net Loss (Barrels)': 0.0}},
#  'kinder morgan co2 co. lp': {2010: {'Net Loss (Barrels)': 325.9},
#   2012: {'Net Loss (Barrels)': 19.03},
#   2013: {'Net Loss (Barrels)': 7.63},
#   2014: {'Net Loss (Barrels)': 2187.8},
#   2015: {'Net Loss (Barrels)': 40.3},
#   2016: {'Net Loss (Barrels)': 294.08}},
#  'tc oil pipeline operations inc': {2010: {'Net Loss (Barrels)': 0.11},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'magellan terminals holdings, lp': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 304.0},
#   2012: {'Net Loss (Barrels)': 0.02},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.08},
#   2015: {'Net Loss (Barrels)': 5.47},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'alyeska pipeline service co': {2010: {'Net Loss (Barrels)': 1119.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'rocky mountain pipeline system, llc': {2010: {'Net Loss (Barrels)': 4.1},
#   2011: {'Net Loss (Barrels)': 0.0}},
#  'amoco oil co': {2010: {'Net Loss (Barrels)': 1241.0}},
#  'citgo products pipeline co': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.24},
#   2013: {'Net Loss (Barrels)': 158.0},
#   2016: {'Net Loss (Barrels)': 0.37}},
#  'suncor energy (usa) pipeline co.': {2010: {'Net Loss (Barrels)': 5.0},
#   2012: {'Net Loss (Barrels)': 5.0}},
#  'west texas gulf pipeline co': {2010: {'Net Loss (Barrels)': 4.0},
#   2011: {'Net Loss (Barrels)': 12.0},
#   2012: {'Net Loss (Barrels)': 3.46},
#   2013: {'Net Loss (Barrels)': 3.1},
#   2014: {'Net Loss (Barrels)': 3.5},
#   2015: {'Net Loss (Barrels)': 216.74},
#   2016: {'Net Loss (Barrels)': 205.0}},
#  'dixie pipeline': {2010: {'Net Loss (Barrels)': 3489.0},
#   2011: {'Net Loss (Barrels)': 22.0}},
#  'oxy usa inc': {2010: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.2}},
#  'white cliffs pipeline, llc': {2010: {'Net Loss (Barrels)': 0.5},
#   2014: {'Net Loss (Barrels)': 4.0},
#   2015: {'Net Loss (Barrels)': 0.1},
#   2016: {'Net Loss (Barrels)': 35.0}},
#  'citgo pipeline co': {2010: {'Net Loss (Barrels)': 0.6},
#   2012: {'Net Loss (Barrels)': 57.0},
#   2015: {'Net Loss (Barrels)': 20.0}},
#  'cenex pipeline llc': {2010: {'Net Loss (Barrels)': 3.63},
#   2012: {'Net Loss (Barrels)': 3.1500000000000004},
#   2013: {'Net Loss (Barrels)': 50.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'nustar terminals operations partnership l. p.': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 2.38},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'ldh energy mont belvieu l.p.': {2010: {'Net Loss (Barrels)': 6.0}},
#  'kinder morgan energy partners, l.p.': {2010: {'Net Loss (Barrels)': 1.0}},
#  'centurion pipeline l.p.': {2010: {'Net Loss (Barrels)': 250.0},
#   2011: {'Net Loss (Barrels)': 990.0},
#   2012: {'Net Loss (Barrels)': 233.0},
#   2014: {'Net Loss (Barrels)': 244.0},
#   2015: {'Net Loss (Barrels)': 294.0},
#   2016: {'Net Loss (Barrels)': 35.0}},
#  'harbor pipeline co': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0}},
#  'enterprise crude pipeline llc': {2010: {'Net Loss (Barrels)': 27.71},
#   2011: {'Net Loss (Barrels)': 11726.97},
#   2012: {'Net Loss (Barrels)': 169.97},
#   2013: {'Net Loss (Barrels)': 9.68},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 226.5},
#   2016: {'Net Loss (Barrels)': 276.0},
#   2017: {'Net Loss (Barrels)': 0.0}},
#  'bp west coast products l.l.c.': {2010: {'Net Loss (Barrels)': 107.0},
#   2011: {'Net Loss (Barrels)': 3.4000000000000004},
#   2013: {'Net Loss (Barrels)': 0.0}},
#  'unocal pipeline co - eastern region': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 4.0}},
#  'coffeyville resources crude transportation, llc': {2010: {'Net Loss (Barrels)': 4.0},
#   2011: {'Net Loss (Barrels)': 2.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'roadrunner pipeline, l.l.c.': {2010: {'Net Loss (Barrels)': 1.0},
#   2013: {'Net Loss (Barrels)': 0.12},
#   2014: {'Net Loss (Barrels)': 1.5},
#   2015: {'Net Loss (Barrels)': 0.25},
#   2016: {'Net Loss (Barrels)': 14.0}},
#  'denbury onshore, llc': {2010: {'Net Loss (Barrels)': 0.29},
#   2011: {'Net Loss (Barrels)': 1.0}},
#  'oiltanking, houston lp': {2010: {'Net Loss (Barrels)': 0.48},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'mid-continent fractionation and storage, l.l.c.': {2010: {'Net Loss (Barrels)': 4.5},
#   2016: {'Net Loss (Barrels)': 140.0}},
#  'mustang pipe line partners': {2010: {'Net Loss (Barrels)': 0.0},
#   2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0}},
#  'buckeye development & logistics, llc': {2011: {'Net Loss (Barrels)': 0.02},
#   2016: {'Net Loss (Barrels)': 2.0}},
#  'buckeye gulf coast pipeline lp': {2011: {'Net Loss (Barrels)': 28.0}},
#  'pipelines of puerto rico incd, the': {2011: {'Net Loss (Barrels)': 26.0}},
#  'dcp midstream': {2011: {'Net Loss (Barrels)': 995.0},
#   2013: {'Net Loss (Barrels)': 12.8},
#   2014: {'Net Loss (Barrels)': 552.6},
#   2015: {'Net Loss (Barrels)': 770.0},
#   2016: {'Net Loss (Barrels)': 305.98}},
#  'equistar chemicals, l.p.': {2011: {'Net Loss (Barrels)': 288.5},
#   2016: {'Net Loss (Barrels)': 6.15}},
#  'transpetco transport co.': {2011: {'Net Loss (Barrels)': 2530.0},
#   2013: {'Net Loss (Barrels)': 26.0}},
#  'denbury green pipeline-texas, llc': {2011: {'Net Loss (Barrels)': 2.4}},
#  'front range pipeline, llc.': {2011: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 2.0}},
#  'denbury gulf coast pipelines, llc': {2011: {'Net Loss (Barrels)': 8.36}},
#  'bp usfo/logistics': {2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 11.0},
#   2013: {'Net Loss (Barrels)': 0.08},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'martin operating partnership, l.p.': {2011: {'Net Loss (Barrels)': 0.0}},
#  'chevron petrochemical pipeline llc': {2011: {'Net Loss (Barrels)': 5.460000000000001},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 6.0}},
#  'kinder morgan cochin llc': {2011: {'Net Loss (Barrels)': 5648.76},
#   2013: {'Net Loss (Barrels)': 253.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.17},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'paramount petroleum corp': {2011: {'Net Loss (Barrels)': 0.9}},
#  'holly energy partners - operating, l.p.': {2011: {'Net Loss (Barrels)': 6.0},
#   2012: {'Net Loss (Barrels)': 561.36},
#   2013: {'Net Loss (Barrels)': 5564.0},
#   2014: {'Net Loss (Barrels)': 793.5},
#   2015: {'Net Loss (Barrels)': 1.88},
#   2016: {'Net Loss (Barrels)': 18.240000000000002}},
#  'wolverine pipeline co': {2011: {'Net Loss (Barrels)': 3.0},
#   2014: {'Net Loss (Barrels)': 9.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'crimson pipeline l.p.': {2011: {'Net Loss (Barrels)': 7.0},
#   2013: {'Net Loss (Barrels)': 15.0},
#   2014: {'Net Loss (Barrels)': 3.28},
#   2015: {'Net Loss (Barrels)': 1.6},
#   2016: {'Net Loss (Barrels)': 375.0}},
#  'mobil chemical co': {2011: {'Net Loss (Barrels)': 0.14},
#   2012: {'Net Loss (Barrels)': 0.2},
#   2013: {'Net Loss (Barrels)': 0.2},
#   2014: {'Net Loss (Barrels)': 4.5}},
#  'seadrift pipeline corp': {2011: {'Net Loss (Barrels)': 1967.0},
#   2015: {'Net Loss (Barrels)': 2.4000000000000004},
#   2016: {'Net Loss (Barrels)': 0.38}},
#  'central florida pipeline corp': {2011: {'Net Loss (Barrels)': 627.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'kern oil & refining co.': {2011: {'Net Loss (Barrels)': 0.5},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'mobil pacific pipeline co': {2011: {'Net Loss (Barrels)': 0.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'valero refining company - california': {2011: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'tidelands oil production company': {2011: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'olympic pipe line company': {2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'chevron midstream pipelines llc': {2011: {'Net Loss (Barrels)': 3.43},
#   2012: {'Net Loss (Barrels)': 3.75},
#   2013: {'Net Loss (Barrels)': 23702.0},
#   2014: {'Net Loss (Barrels)': 0.02}},
#  'motiva enterprise llc': {2011: {'Net Loss (Barrels)': 0.0},
#   2012: {'Net Loss (Barrels)': 23.0},
#   2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'oiltanking port neches, llc': {2011: {'Net Loss (Barrels)': 4.0}},
#  'transmontaigne operating company l.p.': {2011: {'Net Loss (Barrels)': 1330.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'st. james oil corporation': {2011: {'Net Loss (Barrels)': 0.0}},
#  'total petrochemicals pipeline usa , inc.': {2011: {'Net Loss (Barrels)': 1.0}},
#  'enbridge storage (patoka) l.l.c.': {2012: {'Net Loss (Barrels)': 0.0}},
#  'lion oil trading & transportation, inc': {2012: {'Net Loss (Barrels)': 1.0},
#   2013: {'Net Loss (Barrels)': 300.0}},
#  'kinder morgan wink pipeline lp': {2012: {'Net Loss (Barrels)': 7.09},
#   2013: {'Net Loss (Barrels)': 1.25},
#   2014: {'Net Loss (Barrels)': 193.1},
#   2015: {'Net Loss (Barrels)': 13.95}},
#  'petroleum fuel and terminal company': {2012: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'harvest pipeline company': {2012: {'Net Loss (Barrels)': 140.0},
#   2014: {'Net Loss (Barrels)': 2.0},
#   2015: {'Net Loss (Barrels)': 305.07},
#   2016: {'Net Loss (Barrels)': 9.24}},
#  'dixie pipeline company llc': {2012: {'Net Loss (Barrels)': 4.3},
#   2016: {'Net Loss (Barrels)': 4990.11}},
#  'bp pipelines (alaska), inc': {2012: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'citgo petroleum corporation (terminals)': {2012: {'Net Loss (Barrels)': 0.36},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'bridger pipeline llc': {2012: {'Net Loss (Barrels)': 35.0},
#   2015: {'Net Loss (Barrels)': 693.0}},
#  'phillips 66 pipeline llc': {2012: {'Net Loss (Barrels)': 4.84},
#   2013: {'Net Loss (Barrels)': 522.02},
#   2014: {'Net Loss (Barrels)': 6.37},
#   2015: {'Net Loss (Barrels)': 3.13},
#   2016: {'Net Loss (Barrels)': 81.5}},
#  'energy transfer company': {2012: {'Net Loss (Barrels)': 4284.6900000000005},
#   2013: {'Net Loss (Barrels)': 35.379999999999995},
#   2014: {'Net Loss (Barrels)': 3992.0},
#   2015: {'Net Loss (Barrels)': 470.5},
#   2016: {'Net Loss (Barrels)': 764.5}},
#  'rose rock midstream l.p.': {2012: {'Net Loss (Barrels)': 10.0},
#   2013: {'Net Loss (Barrels)': 11.0},
#   2014: {'Net Loss (Barrels)': 23.69},
#   2015: {'Net Loss (Barrels)': 2.2},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'bp oil pipeline co': {2012: {'Net Loss (Barrels)': 0.0}},
#  'the dow chemical company': {2012: {'Net Loss (Barrels)': 132.0},
#   2013: {'Net Loss (Barrels)': 0.0}},
#  'oneok ngl pipeline, llc': {2012: {'Net Loss (Barrels)': 6719.5},
#   2013: {'Net Loss (Barrels)': 17.0},
#   2014: {'Net Loss (Barrels)': 573.54},
#   2015: {'Net Loss (Barrels)': 1669.49},
#   2016: {'Net Loss (Barrels)': 23.369999999999997}},
#  'delek pipeline texas, inc': {2012: {'Net Loss (Barrels)': 5.0}},
#  'tampa bay pipeline co.': {2012: {'Net Loss (Barrels)': 0.1}},
#  'west coast terminal pipeline  (wctp)': {2012: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'energy xxi pipeline, llc': {2012: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'key pipeline limited': {2012: {'Net Loss (Barrels)': 200.0}},
#  'bkep crude, llc': {2012: {'Net Loss (Barrels)': 2.6}},
#  'mobil  pipe  line company': {2012: {'Net Loss (Barrels)': 0.25},
#   2013: {'Net Loss (Barrels)': 1090.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 4.4}},
#  'exxonmobil refining and supply company': {2012: {'Net Loss (Barrels)': 0.0}},
#  'enbridge energy marketing llc': {2012: {'Net Loss (Barrels)': 7.0},
#   2013: {'Net Loss (Barrels)': 0.0}},
#  'delek logistics operating, llc.': {2013: {'Net Loss (Barrels)': 1.2},
#   2014: {'Net Loss (Barrels)': 177.0},
#   2016: {'Net Loss (Barrels)': 22.0}},
#  'genesis pipeline usa, l.p.': {2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 30.0}},
#  'enbridge pipelines (toledo) inc': {2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'collins pipeline co': {2013: {'Net Loss (Barrels)': 0.0}},
#  'cypress interstate pipeline llc': {2013: {'Net Loss (Barrels)': 37.16}},
#  'mccain pipeline company': {2013: {'Net Loss (Barrels)': 50.76}},
#  'citgo petroleum corporation (refinery)': {2013: {'Net Loss (Barrels)': 2.9}},
#  'loop llc': {2013: {'Net Loss (Barrels)': 0.0},
#   2014: {'Net Loss (Barrels)': 0.1},
#   2015: {'Net Loss (Barrels)': 0.04}},
#  'harvest-marks pipeline, llc': {2013: {'Net Loss (Barrels)': 72.0}},
#  'double eagle pipeline llc': {2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 28.3},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'chevron u.s.a. inc': {2013: {'Net Loss (Barrels)': 0.01},
#   2014: {'Net Loss (Barrels)': 0.0}},
#  'tesoro high plains pipeline company llc': {2013: {'Net Loss (Barrels)': 14744.0},
#   2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'tesoro logistics operations llc - southern california': {2013: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'markwest liberty midstream & resources, llc': {2013: {'Net Loss (Barrels)': 11405.0},
#   2016: {'Net Loss (Barrels)': 29.0}},
#  'hfotco llc': {2013: {'Net Loss (Barrels)': 0.0}},
#  'markwest michigan pipeline, llc': {2013: {'Net Loss (Barrels)': 0.0}},
#  'exxonmobil oil corporation-terminals': {2013: {'Net Loss (Barrels)': 20.0}},
#  'genesis free state pipeline, llc': {2013: {'Net Loss (Barrels)': 0.1}},
#  'thunder basin pipeline, llc': {2013: {'Net Loss (Barrels)': 15.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'navajo nation oil and gas company': {2013: {'Net Loss (Barrels)': 1.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'western refining southwest, inc': {2013: {'Net Loss (Barrels)': 2.0},
#   2014: {'Net Loss (Barrels)': 0.5}},
#  'express holdings (usa), llc': {2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'national coop refinery assco': {2014: {'Net Loss (Barrels)': 12.72}},
#  'bkep pipeline, llc': {2014: {'Net Loss (Barrels)': 65.0},
#   2015: {'Net Loss (Barrels)': 14.0}},
#  'targa resources operating llc': {2014: {'Net Loss (Barrels)': 0.0}},
#  'chevron products company - hawaii': {2014: {'Net Loss (Barrels)': 0.0}},
#  'western refining pipeline company': {2014: {'Net Loss (Barrels)': 1.5}},
#  'pacific coast energy company, lp': {2014: {'Net Loss (Barrels)': 3.0}},
#  'glass mountain pipeline': {2014: {'Net Loss (Barrels)': 5.35},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'tri-states ngl pipeline llc': {2014: {'Net Loss (Barrels)': 3.0}},
#  'calumet montana refining, llc': {2014: {'Net Loss (Barrels)': 1.24}},
#  'north dakota pipeline company llc': {2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'jp energy marketing, llc': {2014: {'Net Loss (Barrels)': 20.5},
#   2015: {'Net Loss (Barrels)': 0.0}},
#  'hiland crude, llc': {2014: {'Net Loss (Barrels)': 100.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'kinder morgan crude and condensate llc': {2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'butte pipeline co': {2014: {'Net Loss (Barrels)': 12.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 1.0}},
#  'wyoming pipeline company': {2014: {'Net Loss (Barrels)': 8.5},
#   2015: {'Net Loss (Barrels)': 38.0},
#   2016: {'Net Loss (Barrels)': 11.5}},
#  'laclede gas co': {2014: {'Net Loss (Barrels)': 0.05}},
#  'skeisui specialty chemicals america': {2014: {'Net Loss (Barrels)': 445.27}},
#  'gel offshore pipeline, llc': {2014: {'Net Loss (Barrels)': 0.1}},
#  'chemoil terminals corp.': {2014: {'Net Loss (Barrels)': 389.0}},
#  'genesis pipeline texas, l.p.': {2014: {'Net Loss (Barrels)': 0.0}},
#  'freeport-mcmoran oil & gas': {2014: {'Net Loss (Barrels)': 0.12}},
#  'tesoro socal pipeline company llc': {2014: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'williams field services': {2014: {'Net Loss (Barrels)': 1924.0},
#   2015: {'Net Loss (Barrels)': 1444.85},
#   2016: {'Net Loss (Barrels)': 4.96}},
#  'tallgrass pony express pipeline, llc': {2014: {'Net Loss (Barrels)': 202.62},
#   2015: {'Net Loss (Barrels)': 300.48}},
#  'fieldwood energy, llc': {2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.02}},
#  'dakota gasification company': {2014: {'Net Loss (Barrels)': 1.0}},
#  'enbridge storage (cushing) l.l.c.': {2014: {'Net Loss (Barrels)': 0.0},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'blue racer midstream, llc': {2014: {'Net Loss (Barrels)': 0.0}},
#  'western refining pipeline, llc': {2014: {'Net Loss (Barrels)': 4.92},
#   2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'phillips 66 company - sweeny refinery': {2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'crimson gulf, llc': {2015: {'Net Loss (Barrels)': 220.0},
#   2016: {'Net Loss (Barrels)': 0.5}},
#  'asig - honolulu': {2015: {'Net Loss (Barrels)': 480.0}},
#  'inland corporation': {2015: {'Net Loss (Barrels)': 0.0},
#   2016: {'Net Loss (Barrels)': 0.0}},
#  'double h': {2015: {'Net Loss (Barrels)': 5.58}},
#  'valero refining-texas l.p.': {2015: {'Net Loss (Barrels)': 976.0}},
#  'countrymark refining and logistics, llc': {2015: {'Net Loss (Barrels)': 11.5},
#   2016: {'Net Loss (Barrels)': 0.1}},
#  'ultramar inc': {2015: {'Net Loss (Barrels)': 208.0}},
#  'tesoro logistics operations llc - mountain region': {2015: {'Net Loss (Barrels)': 0.0}},
#  'enbridge pipelines (east texas) l.p.': {2015: {'Net Loss (Barrels)': 0.1}},
#  'enbridge pipelines (southern lights) l.l.c.': {2015: {'Net Loss (Barrels)': 0.0}},
#  'rimrock midstream': {2015: {'Net Loss (Barrels)': 3.0}},
#  'gulf state pipeline co inc': {2015: {'Net Loss (Barrels)': 0.0}},
#  'usg wheatland pipeline, llc': {2015: {'Net Loss (Barrels)': 2.0}},
#  'kinder morgan wink pipeline llc ': {2015: {'Net Loss (Barrels)': 8.0},
#   2016: {'Net Loss (Barrels)': 0.29}},
#  'medallion operating company, llc': {2015: {'Net Loss (Barrels)': 2.0},
#   2016: {'Net Loss (Barrels)': 31.0}},
#  'vitol midstream, llc': {2015: {'Net Loss (Barrels)': 23.0},
#   2016: {'Net Loss (Barrels)': 12.0}},
#  'valero partners operating co. llc': {2015: {'Net Loss (Barrels)': 30.0}},
#  'energy xxi usa, inc': {2015: {'Net Loss (Barrels)': 0.0}},
#  'imtt-bayonne': {2016: {'Net Loss (Barrels)': 395.05}},
#  'nutaaq pipeline, llc': {2016: {'Net Loss (Barrels)': 0.0}},
#  'frontier energy services, l.l.c.': {2016: {'Net Loss (Barrels)': 60.0}},
#  'jp energy permian, llc': {2016: {'Net Loss (Barrels)': 0.0}},
#  'consolidated edison co of ny': {2016: {'Net Loss (Barrels)': 0.0}},
#  'ohio river valley pipeline, llc': {2016: {'Net Loss (Barrels)': 25.0}},
#  'summit midstream partners, llc': {2016: {'Net Loss (Barrels)': 0.0}},
#  'republic midstream, llc': {2016: {'Net Loss (Barrels)': 2.0}},
#  'dow pipeline co - cayuse': {2016: {'Net Loss (Barrels)': 0.7}},
#  'enlink processing services, llc': {2016: {'Net Loss (Barrels)': 47.62}},
#  'thums long beach co': {2016: {'Net Loss (Barrels)': 0.0}},
#  'camino real gathering co llc': {2016: {'Net Loss (Barrels)': 0.0}},
#  'kuraray america, inc. ': {2016: {'Net Loss (Barrels)': 0.0}},
#  'bhp billiton petroleum (eagle ford gathering) llc': {2016: {'Net Loss (Barrels)': 5.6}},
#  'delek crude logistics, llc.': {2016: {'Net Loss (Barrels)': 0.0}},
#  'hawaii independent energy': {2016: {'Net Loss (Barrels)': 2.0}},
#  'itc pipeline company, llc': {2016: {'Net Loss (Barrels)': 0.18}},
#  'torrance valley pipeline company llc': {2016: {'Net Loss (Barrels)': 0.0}},
#  'ngl crude terminals': {2016: {'Net Loss (Barrels)': 0.0}},
#  'texstar midstream logistics, lp': {2016: {'Net Loss (Barrels)': 150.0}},
#  'magellan crude oil pipeline company, l.p.': {2016: {'Net Loss (Barrels)': 0.0}},
#  'tesoro logistics northwest pipeline llc': {2016: {'Net Loss (Barrels)': 0.71}}}

# %%
# Convert the dictionary to a JSON file
with open('spills_per_year.json', 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %%
spill_operators = list(df['Operator Name'].unique())
spill_operators.sort()
spill_operators
# Out:
# ['alyeska pipeline service co',
#  'amoco oil co',
#  'asig - honolulu',
#  'belle fourche pipeline co',
#  'bhp billiton petroleum (eagle ford gathering) llc',
#  'bkep crude, llc',
#  'bkep pipeline, llc',
#  'blue racer midstream, llc',
#  'bp oil pipeline co',
#  'bp pipeline (north america) inc.',
#  'bp pipelines (alaska), inc',
#  'bp usfo/logistics',
#  'bp west coast products l.l.c.',
#  'bridger lake, llc',
#  'bridger pipeline llc',
#  'buckeye development & logistics, llc',
#  'buckeye gulf coast pipeline lp',
#  'buckeye partners, lp',
#  'butte pipeline co',
#  'calnev pipeline co',
#  'calumet montana refining, llc',
#  'camino real gathering co llc',
#  'ccps transportation, llc',
#  'cenex pipeline llc',
#  'central florida pipeline corp',
#  'centurion pipeline l.p.',
#  'chaparral energy, llc',
#  'chemoil terminals corp.',
#  'chevron midstream pipelines llc',
#  'chevron petrochemical pipeline llc',
#  'chevron pipe line co',
#  'chevron products company',
#  'chevron products company - hawaii',
#  'chevron u.s.a. inc',
#  'citgo petroleum corporation (refinery)',
#  'citgo petroleum corporation (terminals)',
#  'citgo pipeline co',
#  'citgo products pipeline co',
#  'coffeyville resources crude transportation, llc',
#  'collins pipeline co',
#  'colonial pipeline co',
#  'conocophillips',
#  'consolidated edison co of ny',
#  'countrymark refining and logistics, llc',
#  'crimson gulf, llc',
#  'crimson pipeline l.p.',
#  'cypress interstate pipeline llc',
#  'dakota gasification company',
#  'dcp midstream',
#  'delek crude logistics, llc.',
#  'delek logistics operating, llc.',
#  'delek pipeline texas, inc',
#  'denbury green pipeline-texas, llc',
#  'denbury gulf coast pipelines, llc',
#  'denbury onshore, llc',
#  'dixie pipeline',
#  'dixie pipeline company llc',
#  'double eagle pipeline llc',
#  'double h',
#  'dow pipeline co - cayuse',
#  'enbridge energy marketing llc',
#  'enbridge energy, limited partnership',
#  'enbridge pipelines (east texas) l.p.',
#  'enbridge pipelines (north dakota) llc',
#  'enbridge pipelines (ozark) l.l.c.',
#  'enbridge pipelines (southern lights) l.l.c.',
#  'enbridge pipelines (toledo) inc',
#  'enbridge storage (cushing) l.l.c.',
#  'enbridge storage (patoka) l.l.c.',
#  'energy transfer company',
#  'energy xxi pipeline, llc',
#  'energy xxi usa, inc',
#  'enlink processing services, llc',
#  'enterprise crude pipeline llc',
#  'enterprise products operating llc',
#  'equistar chemicals, l.p.',
#  'explorer pipeline co',
#  'express holdings (usa), llc',
#  'exxonmobil oil corp - west coast',
#  'exxonmobil oil corporation-terminals',
#  'exxonmobil pipeline co',
#  'exxonmobil refining and supply company',
#  'fieldwood energy, llc',
#  'freeport-mcmoran oil & gas',
#  'front range pipeline, llc.',
#  'frontier energy services, l.l.c.',
#  'gel offshore pipeline, llc',
#  'genesis free state pipeline, llc',
#  'genesis pipeline texas, l.p.',
#  'genesis pipeline usa, l.p.',
#  'glass mountain pipeline',
#  'gulf state pipeline co inc',
#  'harbor pipeline co',
#  'harvest pipeline company',
#  'harvest-marks pipeline, llc',
#  'hawaii independent energy',
#  'hfotco llc',
#  'hiland crude, llc',
#  'holly energy partners - operating, l.p.',
#  'houston refining lp.',
#  'imtt-bayonne',
#  'inland corporation',
#  'itc pipeline company, llc',
#  'jayhawk pipeline llc',
#  'jp energy marketing, llc',
#  'jp energy permian, llc',
#  'kern oil & refining co.',
#  'key pipeline limited',
#  'kiantone pipeline corp',
#  'kinder morgan co2 co. lp',
#  'kinder morgan cochin llc',
#  'kinder morgan crude and condensate llc',
#  'kinder morgan energy partners, l.p.',
#  'kinder morgan liquid terminals, llc',
#  'kinder morgan pipelines (usa) inc',
#  'kinder morgan wink pipeline llc ',
#  'kinder morgan wink pipeline lp',
#  'koch pipeline company, l.p.',
#  'kuraray america, inc. ',
#  'laclede gas co',
#  'ldh energy mont belvieu l.p.',
#  'ldh energy pipeline l.p.',
#  'lion oil trading & transportation, inc',
#  'loop inc',
#  'loop llc',
#  'magellan ammonia pipeline, l.p.',
#  'magellan crude oil pipeline company, l.p.',
#  'magellan pipeline company, lp',
#  'magellan terminals holdings, lp',
#  'marathon pipe line llc',
#  'markwest liberty midstream & resources, llc',
#  'markwest michigan pipeline, llc',
#  'martin operating partnership, l.p.',
#  'mccain pipeline company',
#  'medallion operating company, llc',
#  'mid - valley pipeline co',
#  'mid-continent fractionation and storage, l.l.c.',
#  'mobil  pipe  line company',
#  'mobil chemical co',
#  'mobil corp',
#  'mobil pacific pipeline co',
#  'motiva enterprise llc',
#  'mustang pipe line partners',
#  'national coop refinery assco',
#  'navajo nation oil and gas company',
#  'ngl crude terminals',
#  'north dakota pipeline company llc',
#  'nustar logistics, l.p.',
#  'nustar pipeline operating partnership l.p.',
#  'nustar terminals operations partnership l. p.',
#  'nutaaq pipeline, llc',
#  'ohio river valley pipeline, llc',
#  'oiltanking port neches, llc',
#  'oiltanking, houston lp',
#  'olympic pipe line company',
#  'oneok ngl pipeline lp',
#  'oneok ngl pipeline, llc',
#  'oxy usa inc',
#  'pacific coast energy company, lp',
#  'pacific pipeline system llc',
#  'paramount petroleum corp',
#  'petroleum fuel and terminal company',
#  'petrologistics olefins, llc',
#  'phillips 66 company - sweeny refinery',
#  'phillips 66 pipeline llc',
#  'pipelines of puerto rico incd, the',
#  'plains marketing, l.p.',
#  'plains pipeline, l.p.',
#  'plantation pipe line co',
#  'portland pipeline corp',
#  'progress energy',
#  'republic midstream, llc',
#  'rimrock midstream',
#  'roadrunner pipeline, l.l.c.',
#  'rocky mountain pipeline system, llc',
#  'rose rock midstream l.p.',
#  'seadrift pipeline corp',
#  'semgroup lp',
#  'sfpp, lp',
#  'shell pipeline co., l.p.',
#  'sinclair transportation company',
#  'skeisui specialty chemicals america',
#  'st. james oil corporation',
#  'summit midstream partners, llc',
#  'suncor energy (usa) pipeline co.',
#  'sunoco pipeline l.p.',
#  'sunoco, inc (r&m)',
#  'tallgrass pony express pipeline, llc',
#  'tampa bay pipeline co.',
#  'targa resources operating llc',
#  'targa resources operating lp',
#  'tc oil pipeline operations inc',
#  'te products pipeline company, llc',
#  'teppco crude pipeline, llc',
#  'tesoro - high plains pipeline company',
#  'tesoro high plains pipeline company llc',
#  'tesoro logistics northwest pipeline llc',
#  'tesoro logistics operations llc - mountain region',
#  'tesoro logistics operations llc - southern california',
#  'tesoro socal pipeline company llc',
#  'texstar midstream logistics, lp',
#  'the dow chemical company',
#  'thums long beach co',
#  'thunder basin pipeline, llc',
#  'tidelands oil production company',
#  'torrance valley pipeline company llc',
#  'total petrochemicals pipeline usa , inc.',
#  'transmontaigne operating company l.p.',
#  'transpetco transport co.',
#  'tri-states ngl pipeline llc',
#  'ultramar inc',
#  'unocal pipeline co - eastern region',
#  'usg wheatland pipeline, llc',
#  'valero partners operating co. llc',
#  'valero refining company - california',
#  'valero refining-texas l.p.',
#  'valero terminaling and distribution company',
#  'vitol midstream, llc',
#  'west coast terminal pipeline  (wctp)',
#  'west shore pipeline co',
#  'west texas gulf pipeline co',
#  'western refining pipeline company',
#  'western refining pipeline, llc',
#  'western refining southwest, inc',
#  'white cliffs pipeline, llc',
#  'whitecap pipe line company, l.l.c.',
#  'williams field services',
#  'wolverine pipeline co',
#  'wyoming pipeline company']

# %%
for index, row in df.iterrows():
    
    name = row['Operator Name']
    if name in operators:
        print(name + ' in operators')

# %%
features
# Out:
# [{'type': 'Feature',
#   'id': 1,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10530933.3674226, 3460100.31313749],
#     [-10530817.5951522, 3459954.78573747]]},
#   'properties': {'FID': 1,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.0015401610306,
#    'Distance': 185.96086349063492}},
#  {'type': 'Feature',
#   'id': 2,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10531562.9904625, 3460056.75722927],
#     [-10530933.3674226, 3460100.31313749]]},
#   'properties': {'FID': 2,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.0056662100208,
#    'Distance': 631.127791746932}},
#  {'type': 'Feature',
#   'id': 3,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10528750.6148471, 3452060.33583791],
#     [-10526707.6795521, 3446043.49015274]]},
#   'properties': {'FID': 3,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.0504633329062,
#    'Distance': 6354.212509721492}},
#  {'type': 'Feature',
#   'id': 4,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10526707.6795521, 3446043.49015274],
#     [-10526344.3327342, 3445992.30368581]]},
#   'properties': {'FID': 4,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.00328841846485,
#    'Distance': 366.93455067057306}},
#  {'type': 'Feature',
#   'id': 5,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10526707.6795521, 3446043.49015274],
#     [-10527161.8630745, 3445887.88392146]]},
#   'properties': {'FID': 5,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.00425735316833,
#    'Distance': 480.0999596255327}},
#  {'type': 'Feature',
#   'id': 6,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10527161.8630745, 3445887.88392146],
#     [-10527934.8656186, 3445887.88392146]]},
#   'properties': {'FID': 6,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Texas Intrastate Pipeline Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.00694399999998,
#    'Distance': 773.002544099465}},
#  {'type': 'Feature',
#   'id': 7,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-

#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Centana Pipeline Co (TX)',
#    'Status': 'Operating',
#    'Shape_Leng': 0.0850340218795,
#    'Distance': 10909.530746604085}},
#  {'type': 'Feature',
#   'id': 1004,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-10461822.6653144, 3484637.00669198],
#     [-10462651.8842014, 3485729.44575274]]},
#   'properties': {'FID': 1004,
#    'TYPEPIPE': 'Intrastate',
#    'Operator': 'Centana Pipeline Co (TX)',
#    'Status': 'Operating',
#    'Shape_Leng': 0.0113103811607,
#    'Distance': 1371.5054006565736}},
#  {'type': 'Feature',
#   'id': 1005,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-9058036.68694717, 4615490.1071074],
#     [-9069521.29617333, 4599172.2181773]]},
#   'properties': {'FID': 1005,
#    'TYPEPIPE': 'Interstate',
#    'Operator': 'Dominion Transmission Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.154643707353,
#    'Distance': 19954.191244264308}},
#  {'type': 'Feature',
#   'id': 1006,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-8969137.60951661, 4858080.53206713],
#     [-8984882.86093339, 4867467.64686575]]},
#   'properties': {'FID': 1006,
#    'TYPEPIPE': 'Interstate',
#    'Operator': 'Columbia Gas Trans Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.155503457479,
#    'Distance': 18331.144711121393}},
#  {'type': 'Feature',
#   'id': 1007,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-9053929.66565384, 4635095.53497074],
#     [-9058036.68694717, 4615490.1071074]]},
#   'properties': {'FID': 1007,
#    'TYPEPIPE': 'Interstate',
#    'Operator': 'Dominion Transmission Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.143008962866,
#    'Distance': 20030.986635922305}},
#  {'type': 'Feature',
#   'id': 1008,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-9081604.358982, 4659331.90410486],
#     [-9047164.78019834, 4643235.43122233]]},
#   'properties': {'FID': 1008,
#    'TYPEPIPE': 'Interstate',
#    'Operator': 'Dominion Transmission Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.329419010502,
#    'Distance': 38015.53664035293}},
#  {'type': 'Feature',
#   'id': 1009,
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-9069521.29617333, 4599172.2181773],
#     [-9069945.42343326, 4596217.92679174],
#     [-9070578.72001637, 4591808.58094636],
#     [-9071573.13702763, 4584888.04935637]]},
#   'properties': {'FID': 1009,
#    'TYPEPIPE': 'Interstate',
#    'Operator': 'Dominion Transmission Co',
#    'Status': 'Operating',
#    'Shape_Leng': 0.102660229342,
#    'Distance': 14430.78411934972}},
#  ...]

# %%
# Iterate through the list and dictionary
for name_from_list in spill_operators:
    for name_from_dict in operators:
        similarity_ratio = fuzz.ratio(name_from_list, name_from_dict)
        print(f"Similarity ratio between '{name_from_list}' and '{name_from_dict}': {similarity_ratio}%")
# Out:
# Similarity ratio between 'alyeska pipeline service co' and 'acadian gas gathering system': 25%
# Similarity ratio between 'alyeska pipeline service co' and 'acadian gas pipeline sys': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'acadian haynesville pipeline': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'agua blanca pipeline': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'algonquin gas trans co': 41%
# Similarity ratio between 'alyeska pipeline service co' and 'alliance pipeline system': 59%
# Similarity ratio between 'alyeska pipeline service co' and 'alpine transportation': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'alyeska pipeline': 74%
# Similarity ratio between 'alyeska pipeline service co' and 'amoco pipeline co': 59%
# Similarity ratio between 'alyeska pipeline service co' and 'anr pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'anr storage co': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'arkansas western llc': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'atmos energy (united cities gas co)': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'atmos pipeline - texas': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'birdsboro pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'bison pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'black marlin pipeline co': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'blue dolphin pipeline co': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'bluewater pipeline co': 58%
# Similarity ratio between 'alyeska pipeline service co' and 'bp pipeline (alaska)': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'bp pipeline (north america)': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'bridgeline holdings pipeline lp': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'bridger pipeline': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'brooklyn union gas co': 25%
# Similarity ratio between 'alyeska pipeline service co' and 'butte pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'california gas transmission co': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'canton pipeline': 48%
# Similarity ratio between 'alyeska pipeline service co' and 'canyon creek compression co': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'cardinal pipeline co': 60%
# Similarity ratio between 'alyeska pipeline service co' and 'centana pipeline co (la)': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'centana pipeline co (tx)': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'centra minnesota pipeline co': 58%
# Similarity ratio between 'alyeska pipeline service co' and 'centra pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'centurion pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'chandeleur pipeline co': 61%
# Similarity ratio between 'alyeska pipeline service co' and 'chandeleur pipeline co (mags)': 54%
# Similarity ratio between 'alyeska pipeline service co' and 'cheyenne plains pipeline co': 56%
# Similarity ratio between 'alyeska pipeline service co' and 'chs energy': 22%
# Similarity ratio between 'alyeska pipeline service co' and 'cimarron river pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'colorado interstate gas co': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'columbia gas trans co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'columbia gulf pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'comanche trail pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'constitution pipeline': 42%
# Similarity ratio between 'alyeska pipeline service co' and 'coos county pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'coral energy pipeline co': 59%
# Similarity ratio between 'alyeska pipeline service co' and 'cornerstone pipeline co': 56%
# Similarity ratio between 'alyeska pipeline service co' and 'corpus christi pipeline': 40%
# Similarity ratio between 'alyeska pipeline service co' and 'cove point pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'creole pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'crossroads pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'crosstex alabama system': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'crosstex arkoma system': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'crosstex mississippi pipeline': 39%
# Similarity ratio between 'alyeska pipeline service co' and 'crosstex texas systems': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'dauphin island gathering system': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'delek logistics': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'destin pipeline offshore (shell)': 54%
# Similarity ratio between 'alyeska pipeline service co' and 'discovery pipeline system': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'dominion transmission co': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'dow pipeline co (la)': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'dow pipeline co (tx)': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'east ohio gas co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'east tennessee gas co': 42%
# Similarity ratio between 'alyeska pipeline service co' and 'east west project mainline': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'eastern shore nat gas co': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'el paso natural gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'el paso texas pipeline co': 58%
# Similarity ratio between 'alyeska pipeline service co' and 'elba express pipeline': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'empire pipeline': 48%
# Similarity ratio between 'alyeska pipeline service co' and 'enable gas transmission': 32%
# Similarity ratio between 'alyeska pipeline service co' and 'enbridge': 17%
# Similarity ratio between 'alyeska pipeline service co' and 'enbridge pipelines (alatenn)': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'enbridge pipelines (east texas)': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'enbridge pipelines (utos)': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'energy transfer': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'energynorth nat gas co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'eni us operating': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'enogex inc': 27%
# Similarity ratio between 'alyeska pipeline service co' and 'enterprise products partners': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'epic': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'equitrans inc': 30%
# Similarity ratio between 'alyeska pipeline service co' and 'ergon': 19%
# Similarity ratio between 'alyeska pipeline service co' and 'etc tiger pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'evangeline gas pipeline': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'exxonmobil': 5%
# Similarity ratio between 'alyeska pipeline service co' and 'exxonmobil west coast': 25%
# Similarity ratio between 'alyeska pipeline service co' and 'fayetteville express pipeline': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'florida gas trans co': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'florida southeast connection': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'garden banks auger 1 line': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'gas transmission - northwest': 11%
# Similarity ratio between 'alyeska pipeline service co' and 'genesis energy': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'granite state gas trans co': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'grasslands pipeline': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'great lakes gas trans co': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'guardian pipeline co': 60%
# Similarity ratio between 'alyeska pipeline service co' and 'gulf coast express': 18%
# Similarity ratio between 'alyeska pipeline service co' and 'gulf connector expansion project': 14%
# Similarity ratio between 'alyeska pipeline service co' and 'gulf south pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'gulf xpress': 21%
# Similarity ratio between 'alyeska pipeline service co' and 'gulfstream pipeline co': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'heartland pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'high island offshore': 9%
# Similarity ratio between 'alyeska pipeline service co' and 'holly energy': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'hope natural gas co': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'horizon pipeline co': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'houston pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'hunt crude oil supply': 8%
# Similarity ratio between 'alyeska pipeline service co' and 'hutchinson pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'impulsora pipeline': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'independence trail pipeline co': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'iroquois gas trans co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'kelso-beaver pipeline': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'kenai kachemak pipeline': 48%
# Similarity ratio between 'alyeska pipeline service co' and 'kentucky-west virginia gas co': 32%
# Similarity ratio between 'alyeska pipeline service co' and 'kern river gas trans co': 32%
# Similarity ratio between 'alyeska pipeline service co' and 'keystone gas (sold to in 2005)': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'kinder morgan': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'kinder morgan louisiana pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'kinder morgan texas pipeline co': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'ko transmission co': 36%
# Similarity ratio between 'alyeska pipeline service co' and 'koch pipeline': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'kuparuk transportation': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'loop': 13%
# Similarity ratio between 'alyeska pipeline service co' and 'louisiana gas co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'louisiana intrastate gas co': 41%
# Similarity ratio between 'alyeska pipeline service co' and 'magellan midstream partners': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'marathon': 17%
# Similarity ratio between 'alyeska pipeline service co' and 'maritimes & northeast pl us': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'markwest michigan pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'medallion': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'mgtc pipeline system': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'michcon gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'michigan gas storage co': 36%
# Similarity ratio between 'alyeska pipeline service co' and 'midcontinent express pipeline': 39%
# Similarity ratio between 'alyeska pipeline service co' and 'midla-natchez pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'midwestern gas trans co': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'migc pipeline system': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'millennium pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi canyon gathering': 22%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi canyon gathering (mars)': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi canyon gathering (shell)': 16%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi canyon gathering (ursa)': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi canyon gathering system': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi river trans corp': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'mississippi valley gas co': 27%
# Similarity ratio between 'alyeska pipeline service co' and 'missouri gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'missouri interstate gas, llc': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'missouri pipeline co': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'missouri public service co': 60%
# Similarity ratio between 'alyeska pipeline service co' and 'mojave pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'monterey pipeline co': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'mustang fuel co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'national fuel gas distr co': 42%
# Similarity ratio between 'alyeska pipeline service co' and 'national fuel gas supply co': 37%
# Similarity ratio between 'alyeska pipeline service co' and 'natural gas pl co of am': 36%
# Similarity ratio between 'alyeska pipeline service co' and 'nautilus pipeline system': 59%
# Similarity ratio between 'alyeska pipeline service co' and 'net mexico pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'nexus gas transmission': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'nora transmission co': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'norse pipeline llc': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'north baja pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'north coast gas transmission co': 17%
# Similarity ratio between 'alyeska pipeline service co' and 'north country pipeline co': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'north penn gas co': 41%
# Similarity ratio between 'alyeska pipeline service co' and 'northern border pl co': 29%
# Similarity ratio between 'alyeska pipeline service co' and 'northern illinois gas co': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'northern natural gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'northern utilities (me)': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'northwest pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'northwestern energy co': 41%
# Similarity ratio between 'alyeska pipeline service co' and 'nustar energy': 25%
# Similarity ratio between 'alyeska pipeline service co' and 'oasis pipeline': 54%
# Similarity ratio between 'alyeska pipeline service co' and 'oklahoma texas gas co': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'oneok gas transmission llc': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'oneok gas transportation llc': 25%
# Similarity ratio between 'alyeska pipeline service co' and 'oneok westex pipeline': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'overland trails trans co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'overthrust pipeline co': 57%
# Similarity ratio between 'alyeska pipeline service co' and 'ozark gas transmission, llc': 15%
# Similarity ratio between 'alyeska pipeline service co' and 'paiute pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'panhandle eastern pl co': 40%
# Similarity ratio between 'alyeska pipeline service co' and 'panther interstate pipeline llc': 52%
# Similarity ratio between 'alyeska pipeline service co' and 'pecan pipeline company': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'penn york energy co': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'peoples gas co (tx)': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'permian express partners': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'petal gas storage co': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'phillips  66 pipeline': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'phillips 66 pipeline': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'plains all american pipeline': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'pngts/maritimes & northeast': 19%
# Similarity ratio between 'alyeska pipeline service co' and 'pony express pipeline': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'portland natural gas pl': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'portland pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'public service co of nc': 56%
# Similarity ratio between 'alyeska pipeline service co' and 'public service co of nm': 56%
# Similarity ratio between 'alyeska pipeline service co' and 'questar pipeline co': 65%
# Similarity ratio between 'alyeska pipeline service co' and 'questar southern trails line': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'red bluff express pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'revolution pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'risberg line': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'roadrunner': 22%
# Similarity ratio between 'alyeska pipeline service co' and 'roadrunner eastbound': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'rockies express (echo springs lateral)': 6%
# Similarity ratio between 'alyeska pipeline service co' and 'rockies express (entrega)': 12%
# Similarity ratio between 'alyeska pipeline service co' and 'rockies express pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'rocky mountain natural gas co': 21%
# Similarity ratio between 'alyeska pipeline service co' and 'rover pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'ruby pipeline llc': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'sabal trail pipeline': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'sabine llc': 32%
# Similarity ratio between 'alyeska pipeline service co' and 'san diego gas & elec co': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'sea robin pipeline': 44%
# Similarity ratio between 'alyeska pipeline service co' and 'shell pipeline company': 53%
# Similarity ratio between 'alyeska pipeline service co' and 'shoshone pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'sierrita gas pipeline': 46%
# Similarity ratio between 'alyeska pipeline service co' and 'sonat exploration co': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'south carolina pl corp': 37%
# Similarity ratio between 'alyeska pipeline service co' and 'south georgia gas pipeline co': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'southeast supply header pipeline co': 55%
# Similarity ratio between 'alyeska pipeline service co' and 'southern california gas co': 30%
# Similarity ratio between 'alyeska pipeline service co' and 'southern natural gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'southern pines storage lateral': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'southern star central gas pl co': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'southern union gas services (tx)': 37%
# Similarity ratio between 'alyeska pipeline service co' and 'southwest gas corp': 31%
# Similarity ratio between 'alyeska pipeline service co' and 'spectra energy': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'spire st. louis pipeline': 43%
# Similarity ratio between 'alyeska pipeline service co' and 'st lawrence gas co': 36%
# Similarity ratio between 'alyeska pipeline service co' and 'st. james supply project': 27%
# Similarity ratio between 'alyeska pipeline service co' and 'stingray pipeline': 50%
# Similarity ratio between 'alyeska pipeline service co' and 'stratton ridge': 10%
# Similarity ratio between 'alyeska pipeline service co' and 'sunoco': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'tallgrass energy': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'tallgrass interstate gas transmission': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'tengasco gas co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'tennessee gas pipeline': 49%
# Similarity ratio between 'alyeska pipeline service co' and 'texas eastern trans co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'texas gas transmission co': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'texas intrastate pipeline co': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'texas louisiana markets project': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'the exploration co': 36%
# Similarity ratio between 'alyeska pipeline service co' and 'trailblazer pipeline co': 60%
# Similarity ratio between 'alyeska pipeline service co' and 'trans pecos pipeline': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'transcanada': 21%
# Similarity ratio between 'alyeska pipeline service co' and 'transcolorado gas trans co': 34%
# Similarity ratio between 'alyeska pipeline service co' and 'transcontinental gas pl': 32%
# Similarity ratio between 'alyeska pipeline service co' and 'transok pipeline co': 65%
# Similarity ratio between 'alyeska pipeline service co' and 'transwestern gas co': 35%
# Similarity ratio between 'alyeska pipeline service co' and 'true oil': 17%
# Similarity ratio between 'alyeska pipeline service co' and 'trunkline gas co': 47%
# Similarity ratio between 'alyeska pipeline service co' and 'tuscaloosa pipeline co': 65%
# Similarity ratio between 'alyeska pipeline service co' and 'tuscarora pipeline co': 58%
# Similarity ratio between 'alyeska pipeline service co' and 'union light heat & power': 20%
# Similarity ratio between 'alyeska pipeline service co' and 'usg pipeline co': 62%
# Similarity ratio between 'alyeska pipeline service co' and 'valley crossing pipeline': 51%
# Similarity ratio between 'alyeska pipeline service co' and 'valley gas pipeline co': 65%
# Similarity ratio between 'alyeska pipeline service co' and 'vector pipeline co': 58%
# Similarity ratio between 'alyeska pipeline service co' and 'venice gas gathering sys': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'vermont gas system': 22%
# Similarity ratio between 'alyeska pipeline service co' and 'viking gas transmission co': 38%
# Similarity ratio between 'alyeska pipeline service co' and 'virginia natural gas co': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'wbi energy transmission': 28%
# Similarity ratio between 'alyeska pipeline service co' and 'west ohio gas co': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'west texas gas': 24%
# Similarity ratio between 'alyeska pipeline service co' and 'western gas': 26%
# Similarity ratio between 'alyeska pipeline service co' and 'western refining': 33%
# Similarity ratio between 'alyeska pipeline service co' and 'worsham-steed pipeline': 45%
# Similarity ratio between 'alyeska pipeline service co' and 'wyoming interstate pl co': 31%
# Similarity ratio between 'amoco oil co' and 'acadian gas gathering system': 10%
# Similarity ratio between 'amoco oil co' and 'acadian gas pipeline sys': 33%
# Similarity ratio between 'amoco oil co' and 'acadian haynesville pipeline': 30%
# Similarity ratio between 'amoco oil co' and 'agua blanca pipeline': 31%
# Similarity ratio between 'amoco oil co' and 'algonquin gas trans co': 35%
# Similarity ratio between 'amoco oil co' and 'alliance pipeline system': 11%
# Similarity ratio between 'amoco oil co' and 'alpine transportation': 18%
# Similarity ratio between 'amoco oil co' and 'alyeska pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'amoco pipeline co': 76%
# Similarity ratio between 'amoco oil co' and 'anr pipeline co': 52%
# Similarity ratio between 'amoco oil co' and 'anr storage co': 38%
# Similarity ratio between 'amoco oil co' and 'arkansas western llc': 12%
# Similarity ratio between 'amoco oil co' and 'atmos energy (united cities gas co)': 34%
# Similarity ratio between 'amoco oil co' and 'atmos pipeline - texas': 41%
# Similarity ratio between 'amoco oil co' and 'birdsboro pipeline': 33%
# Similarity ratio between 'amoco oil co' and 'bison pipeline': 31%
# Similarity ratio between 'amoco oil co' and 'black marlin pipeline co': 44%
# Similarity ratio between 'amoco oil co' and 'blue dolphin pipeline co': 39%
# Similarity ratio between 'amoco oil co' and 'bluewater pipeline co': 42%
# Similarity ratio between 'amoco oil co' and 'bp pipeline (alaska)': 12%
# Similarity ratio between 'amoco oil co' and 'bp pipeline (north america)': 15%
# Similarity ratio between 'amoco oil co' and 'bridgeline holdings pipeline lp': 23%
# Similarity ratio between 'amoco oil co' and 'bridger pipeline': 21%
# Similarity ratio between 'amoco oil co' and 'brooklyn union gas co': 24%
# Similarity ratio between 'amoco oil co' and 'butte pipeline': 23%
# Similarity ratio between 'amoco oil co' and 'california gas transmission co': 29%
# Similarity ratio between 'amoco oil co' and 'canton pipeline': 37%
# Similarity ratio between 'amoco oil co' and 'canyon creek compression co': 31%
# Similarity ratio between 'amoco oil co' and 'cardinal pipeline co': 44%
# Similarity ratio between 'amoco oil co' and 'centana pipeline co (la)': 28%
# Similarity ratio between 'amoco oil co' and 'centana pipeline co (tx)': 22%
# Similarity ratio between 'amoco oil co' and 'centra minnesota pipeline co': 45%
# Similarity ratio between 'amoco oil co' and 'centra pipeline co': 47%
# Similarity ratio between 'amoco oil co' and 'centurion pipeline': 27%
# Similarity ratio between 'amoco oil co' and 'chandeleur pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'chandeleur pipeline co (mags)': 20%
# Similarity ratio between 'amoco oil co' and 'cheyenne plains pipeline co': 36%
# Similarity ratio between 'amoco oil co' and 'chs energy': 18%
# Similarity ratio between 'amoco oil co' and 'cimarron river pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'colorado interstate gas co': 37%
# Similarity ratio between 'amoco oil co' and 'columbia gas trans co': 36%
# Similarity ratio between 'amoco oil co' and 'columbia gulf pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'comanche trail pipeline': 34%
# Similarity ratio between 'amoco oil co' and 'constitution pipeline': 30%
# Similarity ratio between 'amoco oil co' and 'coos county pipeline': 38%
# Similarity ratio between 'amoco oil co' and 'coral energy pipeline co': 44%
# Similarity ratio between 'amoco oil co' and 'cornerstone pipeline co': 46%
# Similarity ratio between 'amoco oil co' and 'corpus christi pipeline': 23%
# Similarity ratio between 'amoco oil co' and 'cove point pipeline': 39%
# Similarity ratio between 'amoco oil co' and 'creole pipeline co': 47%
# Similarity ratio between 'amoco oil co' and 'crossroads pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'crosstex alabama system': 17%
# Similarity ratio between 'amoco oil co' and 'crosstex arkoma system': 18%
# Similarity ratio between 'amoco oil co' and 'crosstex mississippi pipeline': 20%
# Similarity ratio between 'amoco oil co' and 'crosstex texas systems': 12%
# Similarity ratio between 'amoco oil co' and 'dauphin island gathering system': 9%
# Similarity ratio between 'amoco oil co' and 'delek logistics': 15%
# Similarity ratio between 'amoco oil co' and 'destin pipeline offshore (shell)': 14%
# Similarity ratio between 'amoco oil co' and 'discovery pipeline system': 32%
# Similarity ratio between 'amoco oil co' and 'dominion transmission co': 33%
# Similarity ratio between 'amoco oil co' and 'dow pipeline co (la)': 31%
# Similarity ratio between 'amoco oil co' and 'dow pipeline co (tx)': 25%
# Similarity ratio between 'amoco oil co' and 'east ohio gas co': 50%
# Similarity ratio between 'amoco oil co' and 'east tennessee gas co': 30%
# Similarity ratio between 'amoco oil co' and 'east west project mainline': 21%
# Similarity ratio between 'amoco oil co' and 'eastern shore nat gas co': 33%
# Similarity ratio between 'amoco oil co' and 'el paso natural gas co': 41%
# Similarity ratio between 'amoco oil co' and 'el paso texas pipeline co': 43%
# Similarity ratio between 'amoco oil co' and 'elba express pipeline': 24%
# Similarity ratio between 'amoco oil co' and 'empire pipeline': 30%
# Similarity ratio between 'amoco oil co' and 'enable gas transmission': 17%
# Similarity ratio between 'amoco oil co' and 'enbridge': 10%
# Similarity ratio between 'amoco oil co' and 'enbridge pipelines (alatenn)': 10%
# Similarity ratio between 'amoco oil co' and 'enbridge pipelines (east texas)': 9%
# Similarity ratio between 'amoco oil co' and 'enbridge pipelines (utos)': 5%
# Similarity ratio between 'amoco oil co' and 'energy transfer': 7%
# Similarity ratio between 'amoco oil co' and 'energynorth nat gas co': 29%
# Similarity ratio between 'amoco oil co' and 'eni us operating': 21%
# Similarity ratio between 'amoco oil co' and 'enogex inc': 18%
# Similarity ratio between 'amoco oil co' and 'enterprise products partners': 5%
# Similarity ratio between 'amoco oil co' and 'epic': 12%
# Similarity ratio between 'amoco oil co' and 'equitrans inc': 16%
# Similarity ratio between 'amoco oil co' and 'ergon': 12%
# Similarity ratio between 'amoco oil co' and 'etc tiger pipeline': 27%
# Similarity ratio between 'amoco oil co' and 'evangeline gas pipeline': 23%
# Similarity ratio between 'amoco oil co' and 'exxonmobil': 36%
# Similarity ratio between 'amoco oil co' and 'exxonmobil west coast': 42%
# Similarity ratio between 'amoco oil co' and 'fayetteville express pipeline': 20%
# Similarity ratio between 'amoco oil co' and 'florida gas trans co': 31%
# Similarity ratio between 'amoco oil co' and 'florida southeast connection': 25%
# Similarity ratio between 'amoco oil co' and 'garden banks auger 1 line': 16%
# Similarity ratio between 'amoco oil co' and 'gas transmission - northwest': 20%
# Similarity ratio between 'amoco oil co' and 'genesis energy': 8%
# Similarity ratio between 'amoco oil co' and 'granite state gas trans co': 26%
# Similarity ratio between 'amoco oil co' and 'grasslands pipeline': 26%
# Similarity ratio between 'amoco oil co' and 'great lakes gas trans co': 33%
# Similarity ratio between 'amoco oil co' and 'guardian pipeline co': 44%
# Similarity ratio between 'amoco oil co' and 'gulf coast express': 27%
# Similarity ratio between 'amoco oil co' and 'gulf connector expansion project': 18%
# Similarity ratio between 'amoco oil co' and 'gulf south pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'gulf xpress': 9%
# Similarity ratio between 'amoco oil co' and 'gulfstream pipeline co': 47%
# Similarity ratio between 'amoco oil co' and 'heartland pipeline co': 42%
# Similarity ratio between 'amoco oil co' and 'high island offshore': 25%
# Similarity ratio between 'amoco oil co' and 'holly energy': 17%
# Similarity ratio between 'amoco oil co' and 'hope natural gas co': 32%
# Similarity ratio between 'amoco oil co' and 'horizon pipeline co': 52%
# Similarity ratio between 'amoco oil co' and 'houston pipeline co': 52%
# Similarity ratio between 'amoco oil co' and 'hunt crude oil supply': 36%
# Similarity ratio between 'amoco oil co' and 'hutchinson pipeline': 26%
# Similarity ratio between 'amoco oil co' and 'impulsora pipeline': 27%
# Similarity ratio between 'amoco oil co' and 'independence trail pipeline co': 29%
# Similarity ratio between 'amoco oil co' and 'iroquois gas trans co': 36%
# Similarity ratio between 'amoco oil co' and 'kelso-beaver pipeline': 24%
# Similarity ratio between 'amoco oil co' and 'kenai kachemak pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'kentucky-west virginia gas co': 24%
# Similarity ratio between 'amoco oil co' and 'kern river gas trans co': 29%
# Similarity ratio between 'amoco oil co' and 'keystone gas (sold to in 2005)': 29%
# Similarity ratio between 'amoco oil co' and 'kinder morgan': 16%
# Similarity ratio between 'amoco oil co' and 'kinder morgan louisiana pipeline': 27%
# Similarity ratio between 'amoco oil co' and 'kinder morgan texas pipeline co': 37%
# Similarity ratio between 'amoco oil co' and 'ko transmission co': 40%
# Similarity ratio between 'amoco oil co' and 'koch pipeline': 40%
# Similarity ratio between 'amoco oil co' and 'kuparuk transportation': 18%
# Similarity ratio between 'amoco oil co' and 'loop': 25%
# Similarity ratio between 'amoco oil co' and 'louisiana gas co': 36%
# Similarity ratio between 'amoco oil co' and 'louisiana intrastate gas co': 31%
# Similarity ratio between 'amoco oil co' and 'magellan midstream partners': 15%
# Similarity ratio between 'amoco oil co' and 'marathon': 20%
# Similarity ratio between 'amoco oil co' and 'maritimes & northeast pl us': 31%
# Similarity ratio between 'amoco oil co' and 'markwest michigan pipeline': 32%
# Similarity ratio between 'amoco oil co' and 'medallion': 19%
# Similarity ratio between 'amoco oil co' and 'mgtc pipeline system': 38%
# Similarity ratio between 'amoco oil co' and 'michcon gas co': 54%
# Similarity ratio between 'amoco oil co' and 'michigan gas storage co': 29%
# Similarity ratio between 'amoco oil co' and 'midcontinent express pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'midla-natchez pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'midwestern gas trans co': 29%
# Similarity ratio between 'amoco oil co' and 'migc pipeline system': 38%
# Similarity ratio between 'amoco oil co' and 'millennium pipeline co': 35%
# Similarity ratio between 'amoco oil co' and 'mississippi canyon gathering': 25%
# Similarity ratio between 'amoco oil co' and 'mississippi canyon gathering (mars)': 21%
# Similarity ratio between 'amoco oil co' and 'mississippi canyon gathering (shell)': 21%
# Similarity ratio between 'amoco oil co' and 'mississippi canyon gathering (ursa)': 21%
# Similarity ratio between 'amoco oil co' and 'mississippi canyon gathering system': 21%
# Similarity ratio between 'amoco oil co' and 'mississippi river trans corp': 20%
# Similarity ratio between 'amoco oil co' and 'mississippi valley gas co': 27%
# Similarity ratio between 'amoco oil co' and 'missouri gas co': 30%
# Similarity ratio between 'amoco oil co' and 'missouri interstate gas, llc': 10%
# Similarity ratio between 'amoco oil co' and 'missouri pipeline co': 50%
# Similarity ratio between 'amoco oil co' and 'missouri public service co': 42%
# Similarity ratio between 'amoco oil co' and 'mojave pipeline co': 53%
# Similarity ratio between 'amoco oil co' and 'monterey pipeline co': 50%
# Similarity ratio between 'amoco oil co' and 'mustang fuel co': 44%
# Similarity ratio between 'amoco oil co' and 'national fuel gas distr co': 37%
# Similarity ratio between 'amoco oil co' and 'national fuel gas supply co': 36%
# Similarity ratio between 'amoco oil co' and 'natural gas pl co of am': 34%
# Similarity ratio between 'amoco oil co' and 'nautilus pipeline system': 22%
# Similarity ratio between 'amoco oil co' and 'net mexico pipeline': 39%
# Similarity ratio between 'amoco oil co' and 'nexus gas transmission': 18%
# Similarity ratio between 'amoco oil co' and 'nora transmission co': 38%
# Similarity ratio between 'amoco oil co' and 'norse pipeline llc': 13%
# Similarity ratio between 'amoco oil co' and 'north baja pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'north coast gas transmission co': 19%
# Similarity ratio between 'amoco oil co' and 'north country pipeline co': 22%
# Similarity ratio between 'amoco oil co' and 'north penn gas co': 28%
# Similarity ratio between 'amoco oil co' and 'northern border pl co': 42%
# Similarity ratio between 'amoco oil co' and 'northern illinois gas co': 39%
# Similarity ratio between 'amoco oil co' and 'northern natural gas co': 29%
# Similarity ratio between 'amoco oil co' and 'northern utilities (me)': 29%
# Similarity ratio between 'amoco oil co' and 'northwest pipeline': 27%
# Similarity ratio between 'amoco oil co' and 'northwestern energy co': 29%
# Similarity ratio between 'amoco oil co' and 'nustar energy': 16%
# Similarity ratio between 'amoco oil co' and 'oasis pipeline': 31%
# Similarity ratio between 'amoco oil co' and 'oklahoma texas gas co': 36%
# Similarity ratio between 'amoco oil co' and 'oneok gas transmission llc': 21%
# Similarity ratio between 'amoco oil co' and 'oneok gas transportation llc': 15%
# Similarity ratio between 'amoco oil co' and 'oneok westex pipeline': 30%
# Similarity ratio between 'amoco oil co' and 'overland trails trans co': 39%
# Similarity ratio between 'amoco oil co' and 'overthrust pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'ozark gas transmission, llc': 21%
# Similarity ratio between 'amoco oil co' and 'paiute pipeline co': 47%
# Similarity ratio between 'amoco oil co' and 'panhandle eastern pl co': 34%
# Similarity ratio between 'amoco oil co' and 'panther interstate pipeline llc': 9%
# Similarity ratio between 'amoco oil co' and 'pecan pipeline company': 41%
# Similarity ratio between 'amoco oil co' and 'penn york energy co': 32%
# Similarity ratio between 'amoco oil co' and 'peoples gas co (tx)': 26%
# Similarity ratio between 'amoco oil co' and 'permian express partners': 17%
# Similarity ratio between 'amoco oil co' and 'petal gas storage co': 31%
# Similarity ratio between 'amoco oil co' and 'phillips  66 pipeline': 18%
# Similarity ratio between 'amoco oil co' and 'phillips 66 pipeline': 19%
# Similarity ratio between 'amoco oil co' and 'plains all american pipeline': 30%
# Similarity ratio between 'amoco oil co' and 'pngts/maritimes & northeast': 15%
# Similarity ratio between 'amoco oil co' and 'pony express pipeline': 24%
# Similarity ratio between 'amoco oil co' and 'portland natural gas pl': 23%
# Similarity ratio between 'amoco oil co' and 'portland pipeline': 28%
# Similarity ratio between 'amoco oil co' and 'public service co of nc': 34%
# Similarity ratio between 'amoco oil co' and 'public service co of nm': 29%
# Similarity ratio between 'amoco oil co' and 'questar pipeline co': 45%
# Similarity ratio between 'amoco oil co' and 'questar southern trails line': 30%
# Similarity ratio between 'amoco oil co' and 'red bluff express pipeline': 16%
# Similarity ratio between 'amoco oil co' and 'revolution pipeline': 32%
# Similarity ratio between 'amoco oil co' and 'risberg line': 17%
# Similarity ratio between 'amoco oil co' and 'roadrunner': 9%
# Similarity ratio between 'amoco oil co' and 'roadrunner eastbound': 12%
# Similarity ratio between 'amoco oil co' and 'rockies express (echo springs lateral)': 24%
# Similarity ratio between 'amoco oil co' and 'rockies express (entrega)': 22%
# Similarity ratio between 'amoco oil co' and 'rockies express pipeline': 28%
# Similarity ratio between 'amoco oil co' and 'rocky mountain natural gas co': 34%
# Similarity ratio between 'amoco oil co' and 'rover pipeline': 31%
# Similarity ratio between 'amoco oil co' and 'ruby pipeline llc': 7%
# Similarity ratio between 'amoco oil co' and 'sabal trail pipeline': 31%
# Similarity ratio between 'amoco oil co' and 'sabine llc': 18%
# Similarity ratio between 'amoco oil co' and 'san diego gas & elec co': 40%
# Similarity ratio between 'amoco oil co' and 'sea robin pipeline': 33%
# Similarity ratio between 'amoco oil co' and 'shell pipeline company': 35%
# Similarity ratio between 'amoco oil co' and 'shoshone pipeline': 34%
# Similarity ratio between 'amoco oil co' and 'sierrita gas pipeline': 24%
# Similarity ratio between 'amoco oil co' and 'sonat exploration co': 38%
# Similarity ratio between 'amoco oil co' and 'south carolina pl corp': 41%
# Similarity ratio between 'amoco oil co' and 'south georgia gas pipeline co': 34%
# Similarity ratio between 'amoco oil co' and 'southeast supply header pipeline co': 30%
# Similarity ratio between 'amoco oil co' and 'southern california gas co': 32%
# Similarity ratio between 'amoco oil co' and 'southern natural gas co': 29%
# Similarity ratio between 'amoco oil co' and 'southern pines storage lateral': 14%
# Similarity ratio between 'amoco oil co' and 'southern star central gas pl co': 33%
# Similarity ratio between 'amoco oil co' and 'southern union gas services (tx)': 14%
# Similarity ratio between 'amoco oil co' and 'southwest gas corp': 27%
# Similarity ratio between 'amoco oil co' and 'spectra energy': 15%
# Similarity ratio between 'amoco oil co' and 'spire st. louis pipeline': 22%
# Similarity ratio between 'amoco oil co' and 'st lawrence gas co': 40%
# Similarity ratio between 'amoco oil co' and 'st. james supply project': 22%
# Similarity ratio between 'amoco oil co' and 'stingray pipeline': 28%
# Similarity ratio between 'amoco oil co' and 'stratton ridge': 31%
# Similarity ratio between 'amoco oil co' and 'sunoco': 33%
# Similarity ratio between 'amoco oil co' and 'tallgrass energy': 14%
# Similarity ratio between 'amoco oil co' and 'tallgrass interstate gas transmission': 12%
# Similarity ratio between 'amoco oil co' and 'tengasco gas co': 52%
# Similarity ratio between 'amoco oil co' and 'tennessee gas pipeline': 24%
# Similarity ratio between 'amoco oil co' and 'texas eastern trans co': 29%
# Similarity ratio between 'amoco oil co' and 'texas gas transmission co': 32%
# Similarity ratio between 'amoco oil co' and 'texas intrastate pipeline co': 35%
# Similarity ratio between 'amoco oil co' and 'texas louisiana markets project': 19%
# Similarity ratio between 'amoco oil co' and 'the exploration co': 33%
# Similarity ratio between 'amoco oil co' and 'trailblazer pipeline co': 34%
# Similarity ratio between 'amoco oil co' and 'trans pecos pipeline': 38%
# Similarity ratio between 'amoco oil co' and 'transcanada': 17%
# Similarity ratio between 'amoco oil co' and 'transcolorado gas trans co': 37%
# Similarity ratio between 'amoco oil co' and 'transcontinental gas pl': 34%
# Similarity ratio between 'amoco oil co' and 'transok pipeline co': 52%
# Similarity ratio between 'amoco oil co' and 'transwestern gas co': 32%
# Similarity ratio between 'amoco oil co' and 'true oil': 40%
# Similarity ratio between 'amoco oil co' and 'trunkline gas co': 29%
# Similarity ratio between 'amoco oil co' and 'tuscaloosa pipeline co': 53%
# Similarity ratio between 'amoco oil co' and 'tuscarora pipeline co': 48%
# Similarity ratio between 'amoco oil co' and 'union light heat & power': 11%
# Similarity ratio between 'amoco oil co' and 'usg pipeline co': 44%
# Similarity ratio between 'amoco oil co' and 'valley crossing pipeline': 28%
# Similarity ratio between 'amoco oil co' and 'valley gas pipeline co': 41%
# Similarity ratio between 'amoco oil co' and 'vector pipeline co': 47%
# Similarity ratio between 'amoco oil co' and 'venice gas gathering sys': 22%
# Similarity ratio between 'amoco oil co' and 'vermont gas system': 27%
# Similarity ratio between 'amoco oil co' and 'viking gas transmission co': 32%
# Similarity ratio between 'amoco oil co' and 'virginia natural gas co': 34%
# Similarity ratio between 'amoco oil co' and 'wbi energy transmission': 17%
# Similarity ratio between 'amoco oil co' and 'west ohio gas co': 43%
# Similarity ratio between 'amoco oil co' and 'west texas gas': 15%
# Similarity ratio between 'amoco oil co' and 'western gas': 9%
# Similarity ratio between 'amoco oil co' and 'western refining': 14%
# Similarity ratio between 'amoco oil co' and 'worsham-steed pipeline': 29%
# Similarity ratio between 'amoco oil co' and 'wyoming interstate pl co': 33%
# Similarity ratio between 'asig - honolulu' and 'acadian gas gathering system': 23%
# Similarity ratio between 'asig - honolulu' and 'acadian gas pipeline sys': 21%
# Similarity ratio between 'asig - honolulu' and 'acadian haynesville pipeline': 33%
# Similarity ratio between 'asig - honolulu' and 'agua blanca pipeline': 17%
# Similarity ratio between 'asig - honolulu' and 'algonquin gas trans co': 27%
# Similarity ratio between 'asig - honolulu' and 'alliance pipeline system': 10%
# Similarity ratio between 'asig - honolulu' and 'alpine transportation': 28%
# Similarity ratio between 'asig - honolulu' and 'alyeska pipeline': 26%
# Similarity ratio between 'asig - honolulu' and 'amoco pipeline co': 25%
# Similarity ratio between 'asig - honolulu' and 'anr pipeline co': 27%
# Similarity ratio between 'asig - honolulu' and 'anr storage co': 34%
# Similarity ratio between 'asig - honolulu' and 'arkansas western llc': 34%
# Similarity ratio between 'asig - honolulu' and 'atmos energy (united cities gas co)': 16%
# Similarity ratio between 'asig - honolulu' and 'atmos pipeline - texas': 32%
# Similarity ratio between 'asig - honolulu' and 'birdsboro pipeline': 18%
# Similarity ratio between 'asig - honolulu' and 'bison pipeline': 28%
# Similarity ratio between 'asig - honolulu' and 'black marlin pipeline co': 26%
# Similarity ratio between 'asig - honolulu' and 'blue dolphin pipeline co': 21%
# Similarity ratio between 'asig - honolulu' and 'bluewater pipeline co': 17%
# Similarity ratio between 'asig - honolulu' and 'bp pipeline (alaska)': 11%
# Similarity ratio between 'asig - honolulu' and 'bp pipeline (north america)': 19%
# Similarity ratio between 'asig - honolulu' and 'bridgeline holdings pipeline lp': 35%
# Similarity ratio between 'asig - honolulu' and 'bridger pipeline': 26%
# Similarity ratio between 'asig - honolulu' and 'brooklyn union gas co': 22%
# Similarity ratio between 'asig - honolulu' and 'butte pipeline': 14%
# Similarity ratio between 'asig - honolulu' and 'california gas transmission co': 27%
# Similarity ratio between 'asig - honolulu' and 'canton pipeline': 27%
# Similarity ratio between 'asig - honolulu' and 'canyon creek compression co': 29%
# Similarity ratio between 'asig - honolulu' and 'cardinal pipeline co': 29%
# Similarity ratio between 'asig - honolulu' and 'centana pipeline co (la)': 26%
# Similarity ratio between 'asig - honolulu' and 'centana pipeline co (tx)': 21%
# Similarity ratio between 'asig - honolulu' and 'centra minnesota pipeline co': 23%
# Similarity ratio between 'asig - honolulu' and 'centra pipeline co': 24%
# Similarity ratio between 'asig - honolulu' and 'centurion pipeline': 24%
# Similarity ratio between 'asig - honolulu' and 'chandeleur pipeline co': 22%
# Similarity ratio between 'asig - honolulu' and 'chandeleur pipeline co (mags)': 9%
# Similarity ratio between 'asig - honolulu' and 'cheyenne plains pipeline co': 24%
# Similarity ratio between 'asig - honolulu' and 'chs energy': 16%
# Similarity ratio between 'asig - honolulu' and 'cimarron river pipeline': 21%
# Similarity ratio between 'asig - honolulu' and 'colorado interstate gas co': 20%
# Similarity ratio between 'asig - honolulu' and 'columbia gas trans co': 17%
# Similarity ratio between 'asig - honolulu' and 'columbia gulf pipeline': 22%
# Similarity ratio between 'asig - honolulu' and 'comanche trail pipeline': 21%
# Similarity ratio between 'asig - honolulu' and 'constitution pipeline': 22%
# Similarity ratio between 'asig - honolulu' and 'coos county pipeline': 17%
# Similarity ratio between 'asig - honolulu' and 'coral energy pipeline co': 21%
# Similarity ratio between 'asig - honolulu' and 'cornerstone pipeline co': 21%
# Similarity ratio between 'asig - honolulu' and 'corpus christi pipeline': 21%
# Similarity ratio between 'asig - honolulu' and 'cove point pipeline': 18%
# Similarity ratio between 'asig - honolulu' and 'creole pipeline co': 18%
# Similarity ratio between 'asig - honolulu' and 'crossroads pipeline co': 27%
# Similarity ratio between 'asig - honolulu' and 'crosstex alabama system': 11%
# ...
# Similarity ratio between 'kern oil & refining co.' and 'wbi energy transmission': 22%
# Similarity ratio between 'kern oil & refining co.' and 'west ohio gas co': 46%
# Similarity ratio between 'kern oil & refining co.' and 'west texas gas': 22%
# Similarity ratio between 'kern oil & refining co.' and 'western gas': 29%
# Similarity ratio between 'kern oil & refining co.' and 'western refining': 62%
# Similarity ratio between 'kern oil & refining co.' and 'worsham-steed pipeline': 27%
# Similarity ratio between 'kern oil & refining co.' and 'wyoming interstate pl co': 30%
# Similarity ratio between 'key pipeline limited' and 'acadian gas gathering system': 25%
# Similarity ratio between 'key pipeline limited' and 'acadian gas pipeline sys': 45%
# Similarity ratio between 'key pipeline limited' and 'acadian haynesville pipeline': 42%
# Similarity ratio between 'key pipeline limited' and 'agua blanca pipeline': 45%
# Similarity ratio between 'key pipeline limited' and 'algonquin gas trans co': 24%
# Similarity ratio between 'key pipeline limited' and 'alliance pipeline system': 59%
# Similarity ratio between 'key pipeline limited' and 'alpine transportation': 29%
# Similarity ratio between 'key pipeline limited' and 'alyeska pipeline': 56%
# Similarity ratio between 'key pipeline limited' and 'amoco pipeline co': 54%
# Similarity ratio between 'key pipeline limited' and 'anr pipeline co': 57%
# Similarity ratio between 'key pipeline limited' and 'anr storage co': 18%
# Similarity ratio between 'key pipeline limited' and 'arkansas western llc': 30%
# Similarity ratio between 'key pipeline limited' and 'atmos energy (united cities gas co)': 29%
# Similarity ratio between 'key pipeline limited' and 'atmos pipeline - texas': 57%
# Similarity ratio between 'key pipeline limited' and 'birdsboro pipeline': 47%
# Similarity ratio between 'key pipeline limited' and 'bison pipeline': 53%
# Similarity ratio between 'key pipeline limited' and 'black marlin pipeline co': 50%
# Similarity ratio between 'key pipeline limited' and 'blue dolphin pipeline co': 50%
# Similarity ratio between 'key pipeline limited' and 'bluewater pipeline co': 54%
# Similarity ratio between 'key pipeline limited' and 'bp pipeline (alaska)': 55%
# Similarity ratio between 'key pipeline limited' and 'bp pipeline (north america)': 47%
# Similarity ratio between 'key pipeline limited' and 'bridgeline holdings pipeline lp': 47%
# Similarity ratio between 'key pipeline limited' and 'bridger pipeline': 56%
# Similarity ratio between 'key pipeline limited' and 'brooklyn union gas co': 29%
# Similarity ratio between 'key pipeline limited' and 'butte pipeline': 59%
# Similarity ratio between 'key pipeline limited' and 'california gas transmission co': 24%
# Similarity ratio between 'key pipeline limited' and 'canton pipeline': 51%
# Similarity ratio between 'key pipeline limited' and 'canyon creek compression co': 13%
# Similarity ratio between 'key pipeline limited' and 'cardinal pipeline co': 50%
# Similarity ratio between 'key pipeline limited' and 'centana pipeline co (la)': 55%
# Similarity ratio between 'key pipeline limited' and 'centana pipeline co (tx)': 55%
# Similarity ratio between 'key pipeline limited' and 'centra minnesota pipeline co': 46%
# Similarity ratio between 'key pipeline limited' and 'centra pipeline co': 58%
# Similarity ratio between 'key pipeline limited' and 'centurion pipeline': 53%
# Similarity ratio between 'key pipeline limited' and 'chandeleur pipeline co': 52%
# Similarity ratio between 'key pipeline limited' and 'chandeleur pipeline co (mags)': 49%
# Similarity ratio between 'key pipeline limited' and 'cheyenne plains pipeline co': 51%
# Similarity ratio between 'key pipeline limited' and 'chs energy': 20%
# Similarity ratio between 'key pipeline limited' and 'cimarron river pipeline': 47%
# Similarity ratio between 'key pipeline limited' and 'colorado interstate gas co': 22%
# Similarity ratio between 'key pipeline limited' and 'columbia gas trans co': 15%
# Similarity ratio between 'key pipeline limited' and 'columbia gulf pipeline': 43%
# Similarity ratio between 'key pipeline limited' and 'comanche trail pipeline': 47%
# Similarity ratio between 'key pipeline limited' and 'constitution pipeline': 44%
# Similarity ratio between 'key pipeline limited' and 'coos county pipeline': 50%
# Similarity ratio between 'key pipeline limited' and 'coral energy pipeline co': 55%
# Similarity ratio between 'key pipeline limited' and 'cornerstone pipeline co': 51%
# Similarity ratio between 'key pipeline limited' and 'corpus christi pipeline': 42%
# Similarity ratio between 'key pipeline limited' and 'cove point pipeline': 51%
# Similarity ratio between 'key pipeline limited' and 'creole pipeline co': 58%
# Similarity ratio between 'key pipeline limited' and 'crossroads pipeline co': 48%
# Similarity ratio between 'key pipeline limited' and 'crosstex alabama system': 9%
# Similarity ratio between 'key pipeline limited' and 'crosstex arkoma system': 10%
# Similarity ratio between 'key pipeline limited' and 'crosstex mississippi pipeline': 41%
# Similarity ratio between 'key pipeline limited' and 'crosstex texas systems': 10%
# Similarity ratio between 'key pipeline limited' and 'dauphin island gathering system': 27%
# Similarity ratio between 'key pipeline limited' and 'delek logistics': 40%
# Similarity ratio between 'key pipeline limited' and 'destin pipeline offshore (shell)': 46%
# Similarity ratio between 'key pipeline limited' and 'discovery pipeline system': 62%
# Similarity ratio between 'key pipeline limited' and 'dominion transmission co': 23%
# Similarity ratio between 'key pipeline limited' and 'dow pipeline co (la)': 55%
# Similarity ratio between 'key pipeline limited' and 'dow pipeline co (tx)': 55%
# Similarity ratio between 'key pipeline limited' and 'east ohio gas co': 22%
# Similarity ratio between 'key pipeline limited' and 'east tennessee gas co': 29%
# Similarity ratio between 'key pipeline limited' and 'east west project mainline': 35%
# Similarity ratio between 'key pipeline limited' and 'eastern shore nat gas co': 23%
# Similarity ratio between 'key pipeline limited' and 'el paso natural gas co': 24%
# Similarity ratio between 'key pipeline limited' and 'el paso texas pipeline co': 49%
# Similarity ratio between 'key pipeline limited' and 'elba express pipeline': 49%
# Similarity ratio between 'key pipeline limited' and 'empire pipeline': 57%
# Similarity ratio between 'key pipeline limited' and 'enable gas transmission': 28%
# Similarity ratio between 'key pipeline limited' and 'enbridge': 21%
# Similarity ratio between 'key pipeline limited' and 'enbridge pipelines (alatenn)': 58%
# Similarity ratio between 'key pipeline limited' and 'enbridge pipelines (east texas)': 51%
# Similarity ratio between 'key pipeline limited' and 'enbridge pipelines (utos)': 53%
# Similarity ratio between 'key pipeline limited' and 'energy transfer': 23%
# Similarity ratio between 'key pipeline limited' and 'energynorth nat gas co': 24%
# Similarity ratio between 'key pipeline limited' and 'eni us operating': 33%
# Similarity ratio between 'key pipeline limited' and 'enogex inc': 27%
# Similarity ratio between 'key pipeline limited' and 'enterprise products partners': 25%
# Similarity ratio between 'key pipeline limited' and 'epic': 25%
# Similarity ratio between 'key pipeline limited' and 'equitrans inc': 24%
# Similarity ratio between 'key pipeline limited' and 'ergon': 16%
# Similarity ratio between 'key pipeline limited' and 'etc tiger pipeline': 53%
# Similarity ratio between 'key pipeline limited' and 'evangeline gas pipeline': 47%
# Similarity ratio between 'key pipeline limited' and 'exxonmobil': 20%
# Similarity ratio between 'key pipeline limited' and 'exxonmobil west coast': 24%
# Similarity ratio between 'key pipeline limited' and 'fayetteville express pipeline': 41%
# Similarity ratio between 'key pipeline limited' and 'florida gas trans co': 15%
# Similarity ratio between 'key pipeline limited' and 'florida southeast connection': 21%
# Similarity ratio between 'key pipeline limited' and 'garden banks auger 1 line': 31%
# Similarity ratio between 'key pipeline limited' and 'gas transmission - northwest': 25%
# Similarity ratio between 'key pipeline limited' and 'genesis energy': 29%
# Similarity ratio between 'key pipeline limited' and 'granite state gas trans co': 17%
# Similarity ratio between 'key pipeline limited' and 'grasslands pipeline': 46%
# Similarity ratio between 'key pipeline limited' and 'great lakes gas trans co': 23%
# Similarity ratio between 'key pipeline limited' and 'guardian pipeline co': 50%
# Similarity ratio between 'key pipeline limited' and 'gulf coast express': 16%
# Similarity ratio between 'key pipeline limited' and 'gulf connector expansion project': 19%
# Similarity ratio between 'key pipeline limited' and 'gulf south pipeline co': 48%
# Similarity ratio between 'key pipeline limited' and 'gulf xpress': 6%
# Similarity ratio between 'key pipeline limited' and 'gulfstream pipeline co': 52%
# Similarity ratio between 'key pipeline limited' and 'heartland pipeline co': 54%
# Similarity ratio between 'key pipeline limited' and 'high island offshore': 5%
# Similarity ratio between 'key pipeline limited' and 'holly energy': 31%
# Similarity ratio between 'key pipeline limited' and 'hope natural gas co': 21%
# Similarity ratio between 'key pipeline limited' and 'horizon pipeline co': 51%
# Similarity ratio between 'key pipeline limited' and 'houston pipeline co': 51%
# Similarity ratio between 'key pipeline limited' and 'hunt crude oil supply': 20%
# Similarity ratio between 'key pipeline limited' and 'hutchinson pipeline': 46%
# Similarity ratio between 'key pipeline limited' and 'impulsora pipeline': 47%
# Similarity ratio between 'key pipeline limited' and 'independence trail pipeline co': 44%
# Similarity ratio between 'key pipeline limited' and 'iroquois gas trans co': 15%
# Similarity ratio between 'key pipeline limited' and 'kelso-beaver pipeline': 54%
# Similarity ratio between 'key pipeline limited' and 'kenai kachemak pipeline': 51%
# Similarity ratio between 'key pipeline limited' and 'kentucky-west virginia gas co': 33%
# Similarity ratio between 'key pipeline limited' and 'kern river gas trans co': 33%
# Similarity ratio between 'key pipeline limited' and 'keystone gas (sold to in 2005)': 32%
# Similarity ratio between 'key pipeline limited' and 'kinder morgan': 36%
# Similarity ratio between 'key pipeline limited' and 'kinder morgan louisiana pipeline': 42%
# Similarity ratio between 'key pipeline limited' and 'kinder morgan texas pipeline co': 47%
# Similarity ratio between 'key pipeline limited' and 'ko transmission co': 26%
# Similarity ratio between 'key pipeline limited' and 'koch pipeline': 61%
# Similarity ratio between 'key pipeline limited' and 'kuparuk transportation': 24%
# Similarity ratio between 'key pipeline limited' and 'loop': 8%
# Similarity ratio between 'key pipeline limited' and 'louisiana gas co': 11%
# Similarity ratio between 'key pipeline limited' and 'louisiana intrastate gas co': 21%
# Similarity ratio between 'key pipeline limited' and 'magellan midstream partners': 21%
# Similarity ratio between 'key pipeline limited' and 'marathon': 7%
# Similarity ratio between 'key pipeline limited' and 'maritimes & northeast pl us': 21%
# Similarity ratio between 'key pipeline limited' and 'markwest michigan pipeline': 48%
# Similarity ratio between 'key pipeline limited' and 'medallion': 28%
# Similarity ratio between 'key pipeline limited' and 'mgtc pipeline system': 60%
# Similarity ratio between 'key pipeline limited' and 'michcon gas co': 12%
# Similarity ratio between 'key pipeline limited' and 'michigan gas storage co': 14%
# Similarity ratio between 'key pipeline limited' and 'midcontinent express pipeline': 41%
# Similarity ratio between 'key pipeline limited' and 'midla-natchez pipeline': 48%
# Similarity ratio between 'key pipeline limited' and 'midwestern gas trans co': 19%
# Similarity ratio between 'key pipeline limited' and 'migc pipeline system': 60%
# Similarity ratio between 'key pipeline limited' and 'millennium pipeline co': 52%
# Similarity ratio between 'key pipeline limited' and 'mississippi canyon gathering': 21%
# Similarity ratio between 'key pipeline limited' and 'mississippi canyon gathering (mars)': 25%
# Similarity ratio between 'key pipeline limited' and 'mississippi canyon gathering (shell)': 18%
# Similarity ratio between 'key pipeline limited' and 'mississippi canyon gathering (ursa)': 22%
# Similarity ratio between 'key pipeline limited' and 'mississippi canyon gathering system': 29%
# Similarity ratio between 'key pipeline limited' and 'mississippi river trans corp': 12%
# Similarity ratio between 'key pipeline limited' and 'mississippi valley gas co': 18%
# Similarity ratio between 'key pipeline limited' and 'missouri gas co': 11%
# Similarity ratio between 'key pipeline limited' and 'missouri interstate gas, llc': 25%
# Similarity ratio between 'key pipeline limited' and 'missouri pipeline co': 50%
# Similarity ratio between 'key pipeline limited' and 'missouri public service co': 26%
# Similarity ratio between 'key pipeline limited' and 'mojave pipeline co': 58%
# Similarity ratio between 'key pipeline limited' and 'monterey pipeline co': 60%
# Similarity ratio between 'key pipeline limited' and 'mustang fuel co': 23%
# Similarity ratio between 'key pipeline limited' and 'national fuel gas distr co': 22%
# Similarity ratio between 'key pipeline limited' and 'national fuel gas supply co': 13%
# Similarity ratio between 'key pipeline limited' and 'natural gas pl co of am': 23%
# Similarity ratio between 'key pipeline limited' and 'nautilus pipeline system': 55%
# Similarity ratio between 'key pipeline limited' and 'net mexico pipeline': 51%
# Similarity ratio between 'key pipeline limited' and 'nexus gas transmission': 24%
# Similarity ratio between 'key pipeline limited' and 'nora transmission co': 20%
# Similarity ratio between 'key pipeline limited' and 'norse pipeline llc': 63%
# Similarity ratio between 'key pipeline limited' and 'north baja pipeline co': 48%
# Similarity ratio between 'key pipeline limited' and 'north coast gas transmission co': 16%
# Similarity ratio between 'key pipeline limited' and 'north country pipeline co': 49%
# Similarity ratio between 'key pipeline limited' and 'north penn gas co': 27%
# Similarity ratio between 'key pipeline limited' and 'northern border pl co': 24%
# Similarity ratio between 'key pipeline limited' and 'northern illinois gas co': 32%
# Similarity ratio between 'key pipeline limited' and 'northern natural gas co': 19%
# Similarity ratio between 'key pipeline limited' and 'northern utilities (me)': 42%
# Similarity ratio between 'key pipeline limited' and 'northwest pipeline': 53%
# Similarity ratio between 'key pipeline limited' and 'northwestern energy co': 14%
# Similarity ratio between 'key pipeline limited' and 'nustar energy': 18%
# Similarity ratio between 'key pipeline limited' and 'oasis pipeline': 53%
# Similarity ratio between 'key pipeline limited' and 'oklahoma texas gas co': 20%
# Similarity ratio between 'key pipeline limited' and 'oneok gas transmission llc': 17%
# Similarity ratio between 'key pipeline limited' and 'oneok gas transportation llc': 17%
# Similarity ratio between 'key pipeline limited' and 'oneok westex pipeline': 54%
# Similarity ratio between 'key pipeline limited' and 'overland trails trans co': 27%
# Similarity ratio between 'key pipeline limited' and 'overthrust pipeline co': 52%
# Similarity ratio between 'key pipeline limited' and 'ozark gas transmission, llc': 30%
# Similarity ratio between 'key pipeline limited' and 'paiute pipeline co': 58%
# Similarity ratio between 'key pipeline limited' and 'panhandle eastern pl co': 23%
# Similarity ratio between 'key pipeline limited' and 'panther interstate pipeline llc': 47%
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
str1 = "portland pipeline"
str2 = "portland pipeline corp"
similarity_ratio = fuzz.ratio(str1, str2)
print(f"The similarity ratio between '{str1}' and '{str2}' is {similarity_ratio}%.")
# Out:
# The similarity ratio between 'portland pipeline' and 'portland pipeline corp' is 87%.
